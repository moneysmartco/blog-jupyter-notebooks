# %% [markdown]
# # Where apply button clicks come from
#
# There's two ways to look at the data, each of which might give slightly different counts:
# * LeadGeneration.ClickConversion from the button click
# * PageView on the ISS page
# * (and also redirect completed on ISS)
#
# The button click event gives more context about where on the page the click happened, while the ISS pageview is the official definition of an action.
#
#
# Events should be defined as per https://docs.google.com/spreadsheets/d/1HICh77BoGMIat9K3NPwz3pBayJWiAr0ohAlTuv7dr80/edit#gid=1692709656, but this hasn't be implemented consistently.
#
# Of note for button clicks / LeadGeneration.ClickConversion:
# * We used to send product_id and provider_id, but with the move to Falcon that doesn't work any longer (or will provide incorrect results).  LPS in particular doesn't seem to have updated the implementation.
# * The product comparison widget in the blog currently doesn't tell us what page it is on
# * Sometimes there is no product or provider info coming through
#
#
# Other things of note:
# * LPS pages don't seem to be categorised as such in the database
#
#
# Outstanding things not necessarily covered below:
# * NPP clicks

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Expand to screen width to fit more on.
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
from datetime import datetime, timedelta
import numpy as np
import pandas as pd
import sqlalchemy

from data_warehouse_querying import DataWarehouseQuery
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
try:
    from pyathena import connect
except:
    print("Failed to import pyathena, trying to install it")
    # !pip install pyathena

import athena_querying  #doing this style as there are connection details within that I want to scope

# %%
from athena_common_queries import *

# %%
import data_parsing

# %% [markdown]
# # Settings

# %%
num_days_to_query = 1
to_datetime = datetime.now().date() - timedelta(days=1) #datetime(year=2020, month=3, day=1)
from_datetime = to_datetime - timedelta(days=num_days_to_query)

# %%
pd.set_option("display.max_colwidth", 200)

# %% [markdown]
# # Database Connections

# %%
# Redshift data warehouse - most queries here
dq = DataWarehouseQuery()
dq.connect()

# %%
# Athena - used for page type analysis
aq = athena_querying.AthenaQuery()
aq.connect()

# %% [markdown]
# # Getting Base Data

# %%
products = dq.query("select * from dim_product")
# Out:
# Starting query at 2020-04-10T08:58:35.958875
# Query took 0.07

# %%
products.head()
# Out:
#    product_id                                   product_name  \
# 0       56622                       CIMB Platinum Mastercard
# 1       70784                Maybank DUO Platinum Mastercard
# 2       75681                                 OCBC 90°N Card
# 3       81857  Citibank Quick Cash (Existing Loan Customers)
# 4       93497                            OCBC ExtraCash Loan
#
#   source_product_id               sys_inserted                sys_updated  \
# 0               101 2019-07-08 19:34:51.551632 2019-07-08 19:34:51.551632
# 1               105 2019-08-16 19:34:45.935610 2019-08-16 19:34:45.935610
# 2               106 2019-08-30 19:34:23.890164 2019-08-30 19:34:23.890164
# 3                24 2019-09-16 19:35:32.751792 2019-09-16 19:35:32.751792
# 4                28 2019-10-18 20:10:55.807708 2019-10-18 20:10:55.807708
#
#    status                                                           slug  \
# 0       0  cimb-platinum-mastercard-212cae7f-f5cd-4dd1-bac3-63033973420e
# 1       1                                maybank-duo-platinum-mastercard
# 2       0                                                 ocbc-90-n-card
# 3       1                         citibank-quick-cash-existing-customers
# 4       0                                           ocbc-extra-cash-loan
#
#    language_id  channel_id  provider_id  country_id
# 0            1           4          102           1
# 1            1           4          107           1
# 2            1           4          108           1
# 3            1          16          836           1
# 4            1          16          833           1

# %%
providers = dq.query("select * from dim_provider")
# Out:
# Starting query at 2020-04-10T08:58:36.262887
# Query took 0.02

# %%
providers.head()
# Out:
#    provider_id            provider_name               sys_inserted  \
# 0          833                     OCBC 2019-02-19 19:32:36.488054
# 1          837  Standard Chartered Bank 2019-02-19 19:32:36.488054
# 2          100  Standard Chartered Bank 2019-01-21 19:32:53.867181
# 3          104                 Citibank 2019-01-21 19:32:53.867181
# 4          255                      AXA 2019-02-01 01:43:57.318499
#
#                  sys_updated  source_provider_id        slug  status  \
# 0 2019-02-19 19:32:36.488054                 6.0        ocbc       1
# 1 2019-02-19 19:32:36.488054                 2.0         scb       1
# 2 2019-01-21 19:32:53.867181                67.0         scb       0
# 3 2019-01-21 19:32:53.867181                56.0    citibank       1
# 4 2019-02-01 01:43:57.318499               259.0  axa-direct       1
#
#    channel_id  country_id  language_id
# 0          16           1            1
# 1          16           1            1
# 2           4           1            1
# 3           4           1            1
# 4          20           1            1

# %%
channels = dq.query("select * from dim_channel")
# Out:
# Starting query at 2020-04-10T08:58:36.518420
# Query took 0.02

# %%
channels.head()
# Out:
#    channel_id       channel_key      channel_name               sys_inserted  \
# 0           4      credit-cards      Credit Cards 2018-09-11 10:11:04.481062
# 1           8  home-equity-loan  Home Equity Loan 2018-09-11 10:11:04.481062
# 2          12    life-insurance    Life Insurance 2018-09-11 10:11:04.481062
# 3          16     personal-loan     Personal Loan 2018-09-11 10:11:04.481062
# 4          20  travel-insurance  Travel Insurance 2018-09-11 10:11:04.481062
#
#                  sys_updated
# 0 2018-09-11 10:11:04.481062
# 1 2018-09-11 10:11:04.481062
# 2 2018-09-11 10:11:04.481062
# 3 2018-09-11 10:11:04.481062
# 4 2018-09-11 10:11:04.481062

# %%
providers_channels = pd.merge(providers, channels, on="channel_id", how="left")

# %%
len(providers)
# Out:
# 496

# %%
len(providers_channels)
# Out:
# 496

# %%
anonymous_users_some = dq.query("select * from dim_anonymous_user limit 1000")
# Out:
# Starting query at 2020-04-10T08:58:38.095673
# Query took 0.02

# %%
anonymous_users_some.head()
# Out:
#    anonymous_user_id                   source_anonymous_id  site_version_id  \
# 0           22568387  2b3a19e2-bc37-44ff-a120-6a14fed9224e                2
# 1           22568399  2b4f8663-a80d-4dd2-8856-30e103b641ec                2
# 2           22568423  2b68a16b-4fcb-485d-8dff-910e59786224                5
# 3           22568452  2b9a0ea4-20de-420e-b226-d28cfb96deb2                1
# 4           22568481  2bba3513-4459-4cce-b938-9e623a24d5af                2
#
#                 sys_inserted                sys_updated
# 0 2019-02-19 19:34:29.494854 2019-02-19 19:34:29.494854
# 1 2019-02-19 19:34:29.494854 2019-02-19 19:34:29.494854
# 2 2019-02-19 19:34:29.494854 2019-02-19 19:34:29.494854
# 3 2019-02-19 19:34:29.494854 2019-02-19 19:34:29.494854
# 4 2019-02-19 19:34:29.494854 2019-02-19 19:34:29.494854

# %%
sessions_some = dq.query("select * from fact_sessions limit 1000")
# Out:
# Starting query at 2020-04-10T08:58:39.291487
# Query took 0.03

# %%
sessions_some.head()
# Out:
#    fact_session_id  session_date_id  session_start_time_id  anonymous_user_id  \
# 0          9075319         20180701                 162018           10188694
# 1          9106274         20180701                 183041           10182610
# 2          9095621         20180701                  51941           10193258
# 3          9087080         20180701                 165234           10181904
# 4          9085606         20180701                 142923           10208464
#
#   user_id  device_id  browser_id  site_country_id  \
# 0    None       2834        8692                1
# 1    None       2835        8684                1
# 2    None       2843        8679                1
# 3    None       2843        8679                1
# 4    None       2843        8679                1
#
#    acquisition_site_version_id  session_landing_page_id  session_campaign_id  \
# 0                            2                   517847               485852
# 1                            1                   517289               485980
# 2                            2                   517793               485852
# 3                            2                   517782               485852
# 4                            2                   516973               485852
#
#    session_count  total_pageviews  total_interaction_events  session_order  \
# 0              1                1                         1              1
# 1              1                5                         8              1
# 2              1                1                         1              1
# 3              1                1                         1              1
# 4              1                1                         1              1
#
#                 sys_inserted                sys_updated  session_id  \
# 0 2018-11-23 11:46:49.078785 2018-11-23 11:46:49.078785    11240374
# 1 2018-11-23 11:46:49.078785 2018-11-23 11:46:49.078785    11247942
# 2 2018-11-23 11:46:49.078785 2020-01-31 11:23:30.531883    11259674
# 3 2018-11-23 11:46:49.078785 2020-01-31 11:23:30.531883    11288167
# 4 2018-11-23 11:46:49.078785 2020-01-31 11:23:30.531883    11276457
#
#    user_filter_type
# 0  external_visitor
# 1  external_visitor
# 2               bot
# 3               bot
# 4               bot

# %%
dim_session_some = dq.query("select * from dim_session limit 1000")
# Out:
# Starting query at 2020-04-10T08:58:40.952405
# Query took 0.02

# %%
dim_session_some.head()
# Out:
#    session_id                                     source_session_id  \
# 0    13678591  d3dba6c5-b233-41ec-80e9-2e22874f606a-180818230837824
# 1    13678595  d3e3be8b-3642-4603-b24b-8d210c80a829-180818154622120
# 2    13678599  d3ebf4a5-da72-4bca-8865-0f5705afc80f-180818191333170
# 3    13678603  d3ece6ff-8966-43e6-a41f-030653ee1e42-180818170633190
# 4    13678607  d3f2d9a2-cd1e-4936-ac88-f5d2c6bcb6f7-180818072726357
#
#   source_session_start_time source_session_end_time  site_version_id  \
# 0   2018-08-18 23:08:37.824     2999-12-31 16:00:00                2
# 1   2018-08-18 15:46:22.120     2999-12-31 16:00:00                1
# 2   2018-08-18 19:13:33.170     2999-12-31 16:00:00                2
# 3   2018-08-18 17:06:33.190     2999-12-31 16:00:00                2
# 4   2018-08-18 07:27:26.357     2999-12-31 16:00:00                2
#
#                 sys_inserted                sys_updated
# 0 2018-11-23 16:44:22.046187 2018-11-23 16:44:22.046187
# 1 2018-11-23 16:44:22.046187 2018-11-23 16:44:22.046187
# 2 2018-11-23 16:44:22.046187 2018-11-23 16:44:22.046187
# 3 2018-11-23 16:44:22.046187 2018-11-23 16:44:22.046187
# 4 2018-11-23 16:44:22.046187 2018-11-23 16:44:22.046187

# %% [markdown]
# # Loading Supporting Data
#
# NB: I'm being a bit liberal with querying excessive data to make it easier; and doing it properly should probably look at other semi-standard views done historically.

# %% [markdown]
# ## Pageviews for session, user and pageview  counts (irrespective of apply) and so conversion rates

# %%
query = """
select 
    fact_activities.page_id
    , page_url
    , dim_page_type.page_type
    , dim_page_type.page_sub_type
    , referrer_page_id
    , session_id
    , fact_activities.anonymous_user_id
    , source_anonymous_id
    , full_date
    , full_time
    , hour24
    , minute
from 
    fact_activities
    left join dim_date on fact_activities.activity_date_id = dim_date.date_id
    left join dim_time on fact_activities.activity_time_id = dim_time.time_id
    left join dim_page on fact_activities.page_id = dim_page.page_id
    left join dim_anonymous_user on fact_activities.anonymous_user_id = dim_anonymous_user.anonymous_user_id
    left join dim_activity_type on fact_activities.activity_type_id = dim_activity_type.activity_type_id
    left join dim_page_type on dim_page_type.page_type_id = dim_page.page_type_id
    -- left join dim_page_
    

where
    dim_activity_type.activity_name = 'PageView'
    and user_filter_type='external_visitor'
    and dim_date.full_date>='{from_date}'
    and dim_date.full_date<='{to_date}'


""".format(from_date= from_datetime.isoformat(), to_date=to_datetime.isoformat())

# %%
print(query)
# Out:
# select
#     fact_activities.page_id
#     , page_url
#     , dim_page_type.page_type
#     , dim_page_type.page_sub_type
#     , referrer_page_id
#     , session_id
#     , fact_activities.anonymous_user_id
#     , source_anonymous_id
#     , full_date
#     , full_time
#     , hour24
#     , minute
# from
#     fact_activities
#     left join dim_date on fact_activities.activity_date_id = dim_date.date_id
#     left join dim_time on fact_activities.activity_time_id = dim_time.time_id
#     left join dim_page on fact_activities.page_id = dim_page.page_id
#     left join dim_anonymous_user on fact_activities.anonymous_user_id = dim_anonymous_user.anonymous_user_id
#     left join dim_activity_type on fact_activities.activity_type_id = dim_activity_type.activity_type_id
#     left join dim_page_type on dim_page_type.page_type_id = dim_page.page_type_id
#     -- left join dim_page_
#
#
# where
#     dim_activity_type.activity_name = 'PageView'
#     and user_filter_type='external_visitor'
#     and dim_date.full_date>='2020-04-08'
#     and dim_date.full_date<='2020-04-09'

# %%
page_views = dq.query(query)
# Out:
# Starting query at 2020-04-10T13:20:15.360733
# Query took 3.84

# %%
page_views.head()
# Out:
#    page_id  \
# 0   517109
# 1  2971487
# 2  2971487
# 3  2971639
# 4  2967216
#
#                                                                       page_url  \
# 0                   blog.moneysmart.sg/budgeting/declare-additional-income-tax
# 1      blog.moneysmart.sg/budgeting/covid-19-financial-assistance-retrenchment
# 2      blog.moneysmart.sg/budgeting/covid-19-financial-assistance-retrenchment
# 3  blog.moneysmart.sg/savings-accounts/dbs-multiplier-ocbc360-uob-one-covid-19
# 4                          blog.moneysmart.sg/budgeting/budget-2020-highlights
#
#    page_type page_sub_type  referrer_page_id  session_id  anonymous_user_id  \
# 0  blog_page          blog               NaN    72032736           22682275
# 1  blog_page          blog               NaN    72066911           22926542
# 2  blog_page          blog               NaN    71891321           23071050
# 3  blog_page          blog               NaN    71897409           23207960
# 4  blog_page          blog               NaN    72013546           22959808
#
#                     source_anonymous_id   full_date full_time  hour24  minute
# 0  1f1ef0f5-fb38-4d5e-9149-609e23bda4f1  2020-04-09  15:42:35      15      42
# 1  63d21cfa-05b6-4aa0-ab37-e0fdac8dcd1e  2020-04-09  22:42:53      22      42
# 2  b9e13651-e817-4f56-95a6-aadf6a6b8a05  2020-04-08  10:39:42      10      39
# 3  0b8c8fff-77ca-4c6c-9bb7-599e824a2018  2020-04-08  12:09:16      12       9
# 4  ed7648a1-31cc-41a2-9b62-a86868a41c53  2020-04-09  13:36:11      13      36

# %%
page_views.agg(["min","max","count", "size"])
# Out:
#        page_id                                  page_url       page_type  \
# min     516315                  blog-admin.moneysmart.sg         Unknown
# max    2971858  www.moneysmart.sg/user-dashboard/profile  thank_you_page
# count   204020                                    204020          204020
# size    204020                                    204020          204020
#
#       page_sub_type  referrer_page_id  session_id  anonymous_user_id  \
# min            None          516315.0    71824989           10177948
# max       thank_you         2971858.0    72114635           61594347
# count        204020           27525.0      204020             204020
# size         204020          204020.0      204020             204020
#
#                         source_anonymous_id   full_date full_time  hour24  \
# min    00003ae1-5271-4f96-b039-2f0fce0241cb  2020-04-08  00:00:00       0
# max    ffffde45-7b44-41fc-83f2-06e6cc06ba92  2020-04-09  23:59:53      23
# count                                204020      204020    204020  204020
# size                                 204020      204020    204020  204020
#
#        minute
# min         0
# max        59
# count  204020
# size   204020

# %%
page_views_referrer_stats = page_views.groupby(["page_type", "page_sub_type"]).agg({"referrer_page_id":["count", "size"]})#.apply(lambda x: x.referrer_page_id.count / x.size)

# %%
page_views_referrer_stats[("referrer_page_id", "fraction_with_referrer_set")] = page_views_referrer_stats[("referrer_page_id", "count")] / page_views_referrer_stats[("referrer_page_id", "size")]

# %%
page_views_referrer_stats
# Out:
#                                    referrer_page_id          \
#                                               count    size
# page_type         page_sub_type
# Unknown           None                         5959   20017
# blog_page         blog                        13186  151393
# details           product_details              1152    6810
# form_page         form                            0      44
# interstitial_page apply                         107     233
#                   redirect                     3542    3748
#                   site                           11      11
# learn_page        learn                          77     385
# listing           category_listing              927    7055
#                   channel_listing              2229   11621
#                   provider_listing              303    2668
# thank_you_page    thank_you                      32      35
#
#
#                                    fraction_with_referrer_set
# page_type         page_sub_type
# Unknown           None                               0.297697
# blog_page         blog                               0.087098
# details           product_details                    0.169163
# form_page         form                               0.000000
# interstitial_page apply                              0.459227
#                   redirect                           0.945037
#                   site                               1.000000
# learn_page        learn                              0.200000
# listing           category_listing                   0.131396
#                   channel_listing                    0.191808
#                   provider_listing                   0.113568
# thank_you_page    thank_you                          0.914286

# %%
page_views[page_views.page_sub_type=="site"]["page_url"]
# Out:
# 6795      www.moneysmart.sg/renovation-loan/maybank/maybank-renovation-loan-monthly-rest/site
# 9406               www.moneysmart.sg/education-loan/posb/posb-loans-further-study-assist/site
# 50836              www.moneysmart.sg/education-loan/posb/posb-loans-further-study-assist/site
# 65700              www.moneysmart.sg/education-loan/posb/posb-loans-further-study-assist/site
# 90878     www.moneysmart.sg/renovation-loan/maybank/maybank-renovation-loan-monthly-rest/site
# 119472             www.moneysmart.sg/education-loan/posb/posb-loans-further-study-assist/site
# 129034             www.moneysmart.sg/education-loan/posb/posb-loans-further-study-assist/site
# 136043             www.moneysmart.sg/education-loan/posb/posb-loans-further-study-assist/site
# 148113    www.moneysmart.sg/renovation-loan/maybank/maybank-renovation-loan-monthly-rest/site
# 157509             www.moneysmart.sg/education-loan/posb/posb-loans-further-study-assist/site
# 184141             www.moneysmart.sg/education-loan/posb/posb-loans-further-study-assist/site
# Name: page_url, dtype: object

# %% [markdown]
# ## Sessions for landing page information
#
# Note that:
# * You can get some of this off the fact_activities
# * You can get a lot of marketing info on the session level
# * For doing per-day etc, you'd likely want the earliest session of the sessions for a user (or do it off pageviews)

# %%
query = """
select
    session_id
    , anonymous_user_id
    , session_landing_page_id
    , session_count
    , dim_date.full_date
    

from 
    fact_sessions
    left join dim_date on session_date_id = dim_date.date_id


where 
    dim_date.full_date>='{from_date}'
    and dim_date.full_date<='{to_date}'

    and user_filter_type='external_visitor'

""".format(from_date= from_datetime.isoformat(), to_date=to_datetime.isoformat())

# %%
print(query)
# Out:
# select
#     session_id
#     , anonymous_user_id
#     , session_landing_page_id
#     , session_count
#     , dim_date.full_date
#
#
# from
#     fact_sessions
#     left join dim_date on session_date_id = dim_date.date_id
#
#
# where
#     dim_date.full_date>='2020-04-08'
#     and dim_date.full_date<='2020-04-09'
#
#     and user_filter_type='external_visitor'

# %%
sessions = dq.query(query)
# Out:
# Starting query at 2020-04-10T13:20:19.859720
# Query took 0.71

# %%
sessions.head()
# Out:
#    session_id  anonymous_user_id  session_landing_page_id  session_count  \
# 0    71827117           61426121                   993224              1
# 1    71894634           61486720                  1227230              1
# 2    71894810           58535310                  1578936              1
# 3    71963603           61435866                  1656230              1
# 4    71894922           61491299                   516766              1
#
#     full_date
# 0  2020-04-08
# 1  2020-04-08
# 2  2020-04-08
# 3  2020-04-08
# 4  2020-04-08

# %%
sessions.agg(["count", "min", "max"])
# Out:
#        session_id  anonymous_user_id  session_landing_page_id  session_count  \
# count      154559             154559                   154559         154559
# min      71824985           10177948                   516315              1
# max      72114635           61594347                  2971854              1
#
#         full_date
# count      154559
# min    2020-04-08
# max    2020-04-09

# %% [markdown]
# ## Better Page Segmentation (should put in ETL sometime)
# For background, current ETL process uses page types from sql pattern matching, but events now send page_type (and in future will try to get page_sub_type) in the event body.  Ticket exists to improve this.

# %% [markdown]
# ### Get All Pages from Data Warehouse

# %%
query = """
select 
    page_id
    , page_url
    , page_type
    , page_sub_type
    -- not joining to get product and category at the moment as not sure its needed.  Data is also in fact_activities
    , product_category_id
    , product_id
    , provider_id
from 
    dim_page
    left join dim_page_type on dim_page.page_type_id = dim_page_type.page_type_id

"""

pages = dq.query(query)
# Out:
# Starting query at 2020-04-10T13:20:28.647670
# Query took 0.27

# %%
pages.count()
# Out:
# page_id                47691
# page_url               47691
# page_type              47691
# page_sub_type          47691
# product_category_id     1251
# product_id              2391
# provider_id             3233
# dtype: int64

# %%
pages.head()
# Out:
#    page_id  \
# 0  1375785
# 1  1647817
# 2  1376813
# 3  1158494
# 4  1378619
#
#                                                                                                                                                                                     page_url  \
# 0  blog.moneysmart.hk/en/mortgage/%E5%B1%85%E5%B1%8B-2019-%E4%BD%95%E6%96%87%E7%94%B0-%E5%B0%87%E8%BB%8D%E6%BE%B3-%E7%94%B3%E8%AB%8B-%E9%A6%AC%E9%9E%8D%E5%B1%B1-%E6%B7%B1%E6%B0%B4%E5%9F%97
# 1                                                                             blog.moneysmart.sg/property/private-properties-hdbs-differences/attachment/private-vs-public-housing-singapore
# 2                                                                                                                                            forum.moneysmart.sg/topic/taking-multiple-loans
# 3                                                                                                    blog.moneysmart.sg/dining/11-best-places-in-singapore-to-get-your-meat-fix-at-1-for-1/_
# 4                                                                                                                                                              www.moneysmart.sg/home%20loan
#
#     page_type page_sub_type  product_category_id  product_id  provider_id
# 0   blog_page          blog                  NaN         NaN          NaN
# 1   blog_page          blog                  NaN         NaN          NaN
# 2  forum_page         forum                  NaN         NaN          NaN
# 3   blog_page          blog                  NaN         NaN          NaN
# 4     Unknown          None                  NaN         NaN          NaN

# %%
pages[pages.page_url.str.startswith("http")].head()
# Out:
# Empty DataFrame
# Columns: [page_id, page_url, page_type, page_sub_type, product_category_id, product_id, provider_id]
# Index: []

# %% [markdown]
# ### Page Type from Event Body (via athena)

# %%
# Just take one day's worth of data from the end of the period (more likely to have updated values than start)
day_to_take_types_from = to_datetime - timedelta(days=1)

query = """
    select 
        context.page_url
        
        --regexp_extract(context.page_url, '^(([^:/?#]+):)?(//([^/?#]*))?([^?#]*)(\?([^#]*))?(#(.*))?', 5)  -- slug
        
        , context.canonical_url
        , body.data.page_type
        , count(*) as event_count
        
        
    from {table_name}
    
    where
        {partition_filter}
        and context.page_url not like '%moneysmart.tw%'
        and context.page_url not like '%moneysmart.ph%'
        and context.page_url not like '%moneysmart.id%'
    
    group by 1,2,3
    

""".format(table_name = athena_querying.athena_database+ "." +athena_querying.athena_raw_events_table,
          partition_filter = create_partition_filter(day_to_take_types_from, to_datetime)
          
          )
           



#could filter out just pageviews, but the group by has the same effect and it's not indexed or anything.

# %%
print(query)
# Out:
#     select
#         context.page_url
#
#         --regexp_extract(context.page_url, '^(([^:/?#]+):)?(//([^/?#]*))?([^?#]*)(\?([^#]*))?(#(.*))?', 5)  -- slug
#
#         , context.canonical_url
#         , body.data.page_type
#         , count(*) as event_count
#
#
#     from ms_data_lake_production.ms_data_stream_production_processed
#
#     where
#
#   (
#  partition_0 >= '2020'
#  AND partition_1 >= '04'
#  AND partition_2 >= '08'
#  OR (
#  partition_0 >= '2020'
#  AND partition_1 > '04'
#  )
#  OR (
#  partition_0 > '2020'
#  )
# )
#  AND ((partition_0 <= '2020'
# 	 AND partition_1 <= '04'
# 	 AND partition_2 <= '09'
# )
#  OR (
# 	 partition_0 <= '2020'
# 	 AND partition_1 < '04'
# )
#  OR (
# 	 partition_0 < '2020'
# )
# )
#         and context.page_url not like '%moneysmart.tw%'
#         and context.page_url not like '%moneysmart.ph%'
#         and context.page_url not like '%moneysmart.id%'
#
#     group by 1,2,3

# %%
pages_types_from_athena_raw = aq.query(query)

# %%
pages_types_from_athena_raw.head()
# Out:
#                                                                                                                        page_url  \
# 0  https://blog.moneysmart.hk/zh-hk/mortgage/%E6%97%A5%E5%87%BA%E5%BA%B7%E5%9F%8E-6%E6%9C%9F-%E9%A0%98%E9%83%BD-montara-malibu/
# 1                                                               https://blog.moneysmart.sg/transportation/motorcycle-singapore/
# 2                                                       https://blog.moneysmart.sg/invest/investment-brokerage-singapore-guide/
# 3                                     https://blog.moneysmart.sg/budgeting/gomo-sim-only-plan/?dclid=COj9hsHg2egCFdsmrQYdep8Ikw
# 4                         https://blog.moneysmart.sg/invest/5-ways-in-which-you-can-make-the-most-of-the-smaller-sgx-lot-sizes/
#
#    canonical_url page_type  event_count
# 0            NaN   article          362
# 1            NaN   article          597
# 2            NaN   article         4118
# 3            NaN   article            5
# 4            NaN   article          136

# %%
# See how much canonical_url is available, but don't want to match as dim_page ATOW isn't using canonical :(
# I think that it was only added for AMP
pages_types_from_athena_raw.count()
# Out:
# page_url         24425
# canonical_url        0
# page_type        18924
# event_count      24425
# dtype: int64

# %%
# Set the dim_page_url for joining
urls_for_dim_page = pages_types_from_athena_raw.apply(lambda x: data_parsing.get_dim_page_url(x["page_url"]), axis=1)

# %%
urls_for_dim_page.head()
# Out:
# 0    blog.moneysmart.hk/zh-hk/mortgage/%e6%97%a5%e5%87%ba%e5%ba%b7%e5%9f%8e-6%e6%9c%9f-%e9%a0%98%e9%83%bd-montara-malibu
# 1                                                                 blog.moneysmart.sg/transportation/motorcycle-singapore
# 2                                                         blog.moneysmart.sg/invest/investment-brokerage-singapore-guide
# 3                                                                        blog.moneysmart.sg/budgeting/gomo-sim-only-plan
# 4                           blog.moneysmart.sg/invest/5-ways-in-which-you-can-make-the-most-of-the-smaller-sgx-lot-sizes
# dtype: object

# %%
# check for bad matching with dim_page (looks like shop url or blog url, but doesn't match)
missing_pages = urls_for_dim_page[~urls_for_dim_page.isin(pages["page_url"])].unique()

# %%
len(missing_pages)
# Out:
# 24

# %%
pd.DataFrame(missing_pages)
# Out:
#                                                                                                                                                                                                          0
# 0                                                                                                                                      blog.moneysmart.sg/%e2%80%a6/icbc-horoscope-credit-card-ca%e2%80%a6
# 1                                                                           blog.moneysmart.hk/zh-hk/credit-cards/%e9%a3%9b%e8%a1%8c%e9%87%8c%e6%95%b8-%e4%bf%a1%e7%94%a8%e5%8d%a1-%e6%af%94%e8%bc%83-2018
# 2                                                                                                           www.moneysmart.hk/zh-hk/lending-companies-loan/lending-companies-loan-plans/promise-easy-loan1
# 3                          blog.moneysmart.hk/zh-hk/investment/%e8%b2%b7%e5%b3%b6-%e7%84%a1%e4%ba%ba%e5%b3%b6-%e5%8a%a0%e5%8b%92%e6%af%94%e6%b5%b7-%e4%b8%ad%e7%be%8e%e6%b4%b2-%e8%8f%b2%e5%be%8b%e8%b3%93
# 4                                       blog.moneysmart.hk/zh-hk/mortgage/%e5%b1%85%e5%b1%8b%e6%8c%89%e6%8f%ad-%e5%88%a9%e7%8e%87-%e5%9b%9e%e8%b4%88-%e9%8a%80%e8%a1%8c/%e2%80%9chttps:/blog.moneysmart.hk
# 5                                                                                                                                          blog.moneysmart.sg/health%20insurance/covid-19-health-insurance
# 6                   blog.moneysmart.hk/zh-hk/credit-cards/didi%e8%bf%8e%e6%96%b0%e5%84%aa%e6%83%a0%e6%b8%9b%e8%87%b326-%e7%94%a8%e6%88%b6%e8%96%a6%e5%8f%8b%e6%88%90%e5%8a%9f%e4%bd%bf%e7%94%a8%e7%8d%b250
# 7                  www.moneysmart.sg/%3ca%20class=%22ui%20blue%20button%22%20target=%22_self%22%20href=%22https://web.archive.org/web/20191225001530/https://blog.moneysmart.sg/%22%3evisit%20blog%3c/a%3e
# 8                                                                                     blog.moneysmart.hk/zh-hk/uncategorized/%e8%b2%b7%e6%a8%93-%e5%8d%b0%e8%8a%b1%e7%a8%85-%e6%8c%89%e6%8f%ad-bsd-ssd-dsd
# 9               blog3.moneysmart.hk/zh-hk/budgeting/%e7%89%9b%e8%82%89%e4%b9%be-%e6%8a%84%e7%89%8c-%e5%8f%b8%e6%a9%9f-%e8%b3%ba%e9%87%8c%e6%95%b8-%e5%9b%9e%e8%b4%88-%e7%bd%b0%e6%ac%be-%e5%8a%a0%e5%83%b9
# 10                                                                    blog.moneysmart.hk/zh-hk/budgeting/%e5%84%aa%e6%83%a0%e7%a2%bc-%e5%a4%96%e8%b3%a3app-delive%e2%80%a6nda-ubereats-e%e8%82%9a%e4%bb%94
# 11        blog.moneysmart.hk/zh-hk/uncategorized/%e5%8a%a0%e6%81%af-%e6%bb%99%e8%b1%90%e9%8a%80%e8%a1%8c-hsbc-%e6%81%92%e7%94%9f%e9%8a%80%e8%a1%8c-hang-seng-bank-dbs-%e4%b8%ad%e5%9c%8b%e9%8a%80%e8%a1%8c
# 12                                                                                                                   www.moneysmart.hk/zh-hk/personal-loan/loan-plans/hsbc-personal-instalment-loan7/apply
# 13                                                             blog.moneysmart.sg/property/investing-singapore-property/what%20factors%20should%20you%20consider%20before%20buying%20a%20second%20property
# 14                                      blog3.moneysmart.hk/zh-hk/investment/%e5%bc%b7%e7%a9%8d%e9%87%91-%e5%bb%b6%e6%9c%9f%e5%b9%b4%e9%87%91-tvc-%e5%ae%8f%e5%88%a9-%e6%af%94%e8%bc%83-%e9%80%80%e4%bc%91
# 15                                                    blog3.moneysmart.hk/zh-hk/credit-cards/%e4%bf%a1%e7%94%a8%e5%8d%a1%e5%b9%b4%e8%b2%bb%e8%b1%81%e5%85%8d-%e6%b0%b8%e4%b9%85%e5%85%8d%e5%b9%b4%e8%b2%bb
# 16                                               blog.moneysmart.hk/zh-hk/ecommerce/%e7%b6%b2%e8%b3%bc%e9%99%b7%e9%98%b1-%e9%bb%91%e5%ba%97%e8%97%89%e3%80%8c%e5%88%b0%e4%bb%98%e3%80%8d%e9%a8%99%e8%b2%a1
# 17  blog3.moneysmart.hk/zh-hk/loans/%e8%ae%80%e7%a2%a9%e5%a3%ab-%e5%8e%bb%e5%8a%a0%e6%8b%bf%e5%a4%a7%e9%80%b2%e4%bf%ae-%e6%8f%80%e5%a4%a7%e5%ad%b8-%e9%96%8b%e6%94%af-%e8%b2%b8%e6%ac%be%e6%af%94%e8%bc%83
# 18       blog.moneysmart.hk/zh-hk/mortgage/%e7%9a%84%e5%a3%ab-%e5%a0%b1%e7%a8%85-%e6%8c%89%e6%8f%ad-freelance-%e9%8a%80%e8%a1%8c/%e2%80%9chttps:/www.moneysmart.hk/zh-hk/credit-cards/annual-fee-waiver-ms
# 19                                                                                                                                                param-16867522.ssr.ias-lab.de/credit-cards/no-annual-fee
# 20                                                blog.moneysmart.hk/https://blog.moneysmart.hk/zh-hk/budgeting/%e9%9f%b3%e6%a8%82%e4%b8%b2%e6%b5%81-apps-%e5%83%b9%e9%8c%a2-%e6%af%94%e8%bc%83-2018-video
# 21                                                                                                                                                                             localhost:3000/credit-cards
# 22                                                                                                                                    blog.moneysmart.sg/%e2%80%a6/singapore-savings-bonds-what-f%e2%80%a6
# 23                                       blog.moneysmart.hk/zh-hk/family/%e9%9b%a2%e5%a9%9a-%e6%89%8b%e7%ba%8c-%e5%be%8b%e5%b8%ab-%e7%a8%8b%e5%ba%8f-%e8%b2%bb%e7%94%a8/%e2%80%9chttps:/blog.moneysmart.hk

# %%
pages[pages.page_url.isin([z.strip("/") for z in missing_pages])]
# Out:
# Empty DataFrame
# Columns: [page_id, page_url, page_type, page_sub_type, product_category_id, product_id, provider_id]
# Index: []

# %%
pages[pages.page_url=="www.moneysmart.sg/"]
# Out:
#        page_id            page_url page_type page_sub_type  \
# 20791   663410  www.moneysmart.sg/   Unknown          None
#
#        product_category_id  product_id  provider_id
# 20791                  NaN         NaN          NaN

# %%
pages[pages.page_url=="www.moneysmart.sg"]
# Out:
#        page_id           page_url page_type page_sub_type  \
# 37822   521077  www.moneysmart.sg   Unknown          None
#
#        product_category_id  product_id  provider_id
# 37822                  NaN         NaN          NaN

# %%
len(pages_types_from_athena_raw)
# Out:
# 24425

# %%
# Group together and remove duplicate entries sensibly

# %%
pages_types_from_athena_raw.head()
# Out:
#                                                                                                                        page_url  \
# 0  https://blog.moneysmart.hk/zh-hk/mortgage/%E6%97%A5%E5%87%BA%E5%BA%B7%E5%9F%8E-6%E6%9C%9F-%E9%A0%98%E9%83%BD-montara-malibu/
# 1                                                               https://blog.moneysmart.sg/transportation/motorcycle-singapore/
# 2                                                       https://blog.moneysmart.sg/invest/investment-brokerage-singapore-guide/
# 3                                     https://blog.moneysmart.sg/budgeting/gomo-sim-only-plan/?dclid=COj9hsHg2egCFdsmrQYdep8Ikw
# 4                         https://blog.moneysmart.sg/invest/5-ways-in-which-you-can-make-the-most-of-the-smaller-sgx-lot-sizes/
#
#    canonical_url page_type  event_count
# 0            NaN   article          362
# 1            NaN   article          597
# 2            NaN   article         4118
# 3            NaN   article            5
# 4            NaN   article          136

# %%
pages_types_from_athena_processing = pages_types_from_athena_raw[["page_url", "page_type", "event_count"]]

# %%
pages_types_from_athena_processing.rename(columns={"page_type":"page_type_from_events", "event_count":"event_count_athena"}, inplace=True)
pages_types_from_athena_processing.columns
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# Index(['page_url', 'page_type_from_events', 'event_count_athena'], dtype='object')

# %%
pages_types_from_athena_processing["dim_page_url"] = urls_for_dim_page
pages_types_from_athena_processing.head()
# Out:
#                                                                                                                        page_url  \
# 0  https://blog.moneysmart.hk/zh-hk/mortgage/%E6%97%A5%E5%87%BA%E5%BA%B7%E5%9F%8E-6%E6%9C%9F-%E9%A0%98%E9%83%BD-montara-malibu/
# 1                                                               https://blog.moneysmart.sg/transportation/motorcycle-singapore/
# 2                                                       https://blog.moneysmart.sg/invest/investment-brokerage-singapore-guide/
# 3                                     https://blog.moneysmart.sg/budgeting/gomo-sim-only-plan/?dclid=COj9hsHg2egCFdsmrQYdep8Ikw
# 4                         https://blog.moneysmart.sg/invest/5-ways-in-which-you-can-make-the-most-of-the-smaller-sgx-lot-sizes/
#
#   page_type_from_events  event_count_athena  \
# 0               article                 362
# 1               article                 597
# 2               article                4118
# 3               article                   5
# 4               article                 136
#
#                                                                                                           dim_page_url
# 0  blog.moneysmart.hk/zh-hk/mortgage/%e6%97%a5%e5%87%ba%e5%ba%b7%e5%9f%8e-6%e6%9c%9f-%e9%a0%98%e9%83%bd-montara-malibu
# 1                                                               blog.moneysmart.sg/transportation/motorcycle-singapore
# 2                                                       blog.moneysmart.sg/invest/investment-brokerage-singapore-guide
# 3                                                                      blog.moneysmart.sg/budgeting/gomo-sim-only-plan
# 4                         blog.moneysmart.sg/invest/5-ways-in-which-you-can-make-the-most-of-the-smaller-sgx-lot-sizes

# %%
page_types_from_athena = pages_types_from_athena_processing.fillna("").groupby(["dim_page_url"]).agg({"event_count_athena":"sum", "page_type_from_events":"max" }).reset_index()

# %%
page_types_from_athena.head()
# Out:
#                                                                                dim_page_url  \
# 0                                                                  blog-admin.moneysmart.sg
# 1  blog-admin.moneysmart.sg/credit-cards/letting-loose-long-week-heres-dont-need-worry-cost
# 2                   blog-admin.moneysmart.sg/credit-cards/uob-prvi-miles-credit-card-review
# 3             blog-admin.moneysmart.sg/fixed-deposits/best-fixed-deposit-accounts-singapore
# 4         blog-admin.moneysmart.sg/savings-accounts/dbs-multiplier-ocbc360-uob-one-covid-19
#
#    event_count_athena page_type_from_events
# 0                   6                  home
# 1                   1               article
# 2                   2  blog-article-details
# 3                   3               article
# 4                  10  blog-article-details

# %%
#using fillna because it was erroring on max
page_types_from_athena.groupby("page_type_from_events").agg({"event_count_athena":"sum", "dim_page_url":"count"})
# Out:
#                              event_count_athena  dim_page_url
# page_type_from_events
#                                           62178           721
# article                                  298841          2325
# blog-article-details                     174943           185
# blog-post-page                           212794            92
# category                                   2017            83
# claim-status-tracker                        178             1
# claim-status-tracker-result                  23             1
# contact-us-general-enquiry                  110             1
# home                                        280             5
# interstitial-page                          5141           165
# lps                                        2819            62
# other                                      3567            72
# product-details                           10974           297
# product-listing                           22874           473
# tag                                         306            41

# %% [markdown]
# ### Page Type from Jamie's Logic
#
# This was originally done for understanding segment vs kinesis, and then has been tweaked to add a bit more.
#
# AToW it defaults to shop if it can't categorise better.

# %%
# Expect this to be a bit slow
page_types_jamie = pages[["page_id", "page_url"]].reset_index()

# %%
jamie_types = pages.apply(lambda x:data_parsing.get_metadata_from_url("https://"+x.page_url)[0], axis=1) #[page_type, slug, slug_root, ab_test, country_code]
#page_types_jamie["page_type"] = jamie_types

# %%
page_types_jamie["page_type_jamie"] = jamie_types

# %%
len(page_types_jamie)
# Out:
# 47691

# %%
page_types_jamie.columns
# Out:
# Index(['index', 'page_id', 'page_url', 'page_type_jamie'], dtype='object')

# %%
# NB: logic is a bit flakey as it defaults to shop
page_types_jamie.groupby("page_type_jamie").size()
# Out:
# page_type_jamie
# blog_category_page          267
# blog_category_tag_page    25798
# blog_home_page                4
# blog_tag_page               115
# calculator                   28
# embed                       255
# home_page                    30
# iss                        2789
# learn                       446
# lps                         184
# shop                      17373
# trend                         8
# unbounce                    394
# dtype: int64

# %% [markdown]
# ### Merged Page Type

# %%
# could probably merge techniques to use Jamie style plus PDP and listing page from the data warehouse
# essentially take the athena one and if not present, then use the Jamie one

pages_types_combined = pages.merge(page_types_jamie[["page_id", "page_type_jamie"]], how="left", on="page_id")\
    .merge(page_types_from_athena, how="left", left_on="page_url", right_on="dim_page_url")

# %%
pages_types_combined.head()
# Out:
#    page_id  \
# 0  1375785
# 1  1647817
# 2  1376813
# 3  1158494
# 4  1378619
#
#                                                                                                                                                                                     page_url  \
# 0  blog.moneysmart.hk/en/mortgage/%E5%B1%85%E5%B1%8B-2019-%E4%BD%95%E6%96%87%E7%94%B0-%E5%B0%87%E8%BB%8D%E6%BE%B3-%E7%94%B3%E8%AB%8B-%E9%A6%AC%E9%9E%8D%E5%B1%B1-%E6%B7%B1%E6%B0%B4%E5%9F%97
# 1                                                                             blog.moneysmart.sg/property/private-properties-hdbs-differences/attachment/private-vs-public-housing-singapore
# 2                                                                                                                                            forum.moneysmart.sg/topic/taking-multiple-loans
# 3                                                                                                    blog.moneysmart.sg/dining/11-best-places-in-singapore-to-get-your-meat-fix-at-1-for-1/_
# 4                                                                                                                                                              www.moneysmart.sg/home%20loan
#
#     page_type page_sub_type  product_category_id  product_id  provider_id  \
# 0   blog_page          blog                  NaN         NaN          NaN
# 1   blog_page          blog                  NaN         NaN          NaN
# 2  forum_page         forum                  NaN         NaN          NaN
# 3   blog_page          blog                  NaN         NaN          NaN
# 4     Unknown          None                  NaN         NaN          NaN
#
#           page_type_jamie dim_page_url  event_count_athena  \
# 0  blog_category_tag_page          NaN                 NaN
# 1  blog_category_tag_page          NaN                 NaN
# 2                    shop          NaN                 NaN
# 3  blog_category_tag_page          NaN                 NaN
# 4                    shop          NaN                 NaN
#
#   page_type_from_events
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %% [markdown]
# ### Comparing all the techniques
# Intent here is to go back and make one technique that solves this for all pages

# %%
pages_types_combined.groupby(["page_type", "page_sub_type", "page_type_jamie", "page_type_from_events"])\
.agg({"page_id":"count","event_count_athena":"sum"}).reset_index().rename(columns={"page_id":"page_count"})
# Out:
#             page_type     page_sub_type         page_type_jamie  \
# 0             Unknown              None              calculator
# 1             Unknown              None                   embed
# 2             Unknown              None                   embed
# 3             Unknown              None               home_page
# 4             Unknown              None                     lps
# 5             Unknown              None                     lps
# 6             Unknown              None                    shop
# 7             Unknown              None                    shop
# 8             Unknown              None                    shop
# 9             Unknown              None                    shop
# 10            Unknown              None                    shop
# 11            Unknown              None                    shop
# 12            Unknown              None                    shop
# 13            Unknown              None                   trend
# 14            Unknown              None                unbounce
# 15          blog_page              blog      blog_category_page
# 16          blog_page              blog      blog_category_page
# 17          blog_page              blog  blog_category_tag_page
# 18          blog_page              blog  blog_category_tag_page
# 19          blog_page              blog  blog_category_tag_page
# 20          blog_page              blog  blog_category_tag_page
# 21          blog_page              blog  blog_category_tag_page
# 22          blog_page              blog  blog_category_tag_page
# 23          blog_page              blog  blog_category_tag_page
# 24          blog_page              blog          blog_home_page
# 25          blog_page              blog          blog_home_page
# 26          blog_page              blog          blog_home_page
# 27          blog_page              blog           blog_tag_page
# 28          blog_page              blog               home_page
# 29          blog_page              blog                    shop
# 30          blog_page              blog                    shop
# 31            details   product_details                    shop
# 32            details   product_details                    shop
# 33          form_page              form                    shop
# 34  interstitial_page             apply                     iss
# 35  interstitial_page          redirect                     iss
# 36  interstitial_page          redirect                     iss
# 37  interstitial_page              site                    shop
# 38         learn_page             learn               home_page
# 39         learn_page             learn                   learn
# 40            listing  category_listing                    shop
# 41            listing   channel_listing                    shop
# 42            listing   channel_listing                    shop
# 43            listing  provider_listing                    shop
# 44            listing  provider_listing                    shop
# 45            listing  provider_listing                unbounce
# 46     thank_you_page         thank_you                    shop
#
#           page_type_from_events  page_count  event_count_athena
# 0                                         9              2675.0
# 1                                        11              2747.0
# 2                blog-post-page          92            212794.0
# 3                                         1              2315.0
# 4                                        80              1416.0
# 5                           lps          61              2805.0
# 6                                       142             12150.0
# 7          claim-status-tracker           1               178.0
# 8   claim-status-tracker-result           1                23.0
# 9    contact-us-general-enquiry           1               110.0
# 10                          lps           1                14.0
# 11              product-details         162              3658.0
# 12              product-listing         120              1511.0
# 13                                        3               820.0
# 14                                       48              1879.0
# 15                                        3                 3.0
# 16                     category          35               810.0
# 17                                      204             33832.0
# 18                      article        2318            298821.0
# 19         blog-article-details         183            174931.0
# 20                     category          48              1207.0
# 21                         home           3                 4.0
# 22                        other          63               442.0
# 23                          tag          41               306.0
# 24                                        1                 8.0
# 25                         home           1               270.0
# 26                        other           1              3105.0
# 27                                        4                 4.0
# 28                         home           1                 6.0
# 29                      article           2                 4.0
# 30         blog-article-details           2                12.0
# 31              product-details         135              7316.0
# 32              product-listing           2                27.0
# 33                                        1                71.0
# 34                                       59               409.0
# 35                                       39                92.0
# 36            interstitial-page         165              5141.0
# 37                                        2                32.0
# 38                                        1                39.0
# 39                                       62               351.0
# 40              product-listing         232              7486.0
# 41                                       14              3084.0
# 42              product-listing          60             11081.0
# 43                                       24               155.0
# 44              product-listing          57              2704.0
# 45                                        1                 2.0
# 46                                        3                58.0

# %%
# ^ It's going to take some work to resolve it well

# %%
ptc = pages_types_combined

# %%
ptc[(ptc.page_type == "Unknown") & (ptc.page_type_from_events == "product-listing")]
# Out:
#        page_id  \
# 2674    517337
# 35659  2963823
# 36721  1583842
# 36768  1540787
# 36938  1797374
# 37020  1582609
# 37147  2803554
# 37182  1802404
# 40379  1435624
# 40420  1580332
# 40862  1623914
# 40863  1625043
# 40980  1673296
# 41006  1798332
# 41079  1532085
# 41329  2788055
# 41408  1792727
# 41461  2704242
# 41466  2805717
# 41895  2969119
# 41909  2968720
# 41979  2969044
# 41981  2969092
# 42001  2969627
# 42068  2969281
# 42095  2969365
# 42334  2538352
# 42343  2970145
# 42347  2970882
# 42366  2970472
# ...        ...
# 46200  2971208
# 46380  2704020
# 46386  2806106
# 46387  2808035
# 46446  2804429
# 46563  2802896
# 46833  2966854
# 46939  2968680
# 47014  2968877
# 47027  2969160
# 47031  2969511
# 47035  2969579
# 47098  2969923
# 47106  2969516
# 47350  1629607
# 47351  1635830
# 47352  2513553
# 47353  1641262
# 47354  2534937
# 47368  2970847
# 47384  2951536
# 47468  1623414
# 47490  2970353
# 47491  2970369
# 47494  2971015
# 47498  2971082
# 47502  2970584
# 47596  2970725
# 47606  2971514
# 47686  2971830
#
#                                                                                page_url  \
# 2674                                              www.moneysmart.sg/savings-account/rhb
# 35659                      www.moneysmart.sg/debt-consolidation-plan/standard-chartered
# 36721                                www.moneysmart.hk/zh-hk/credit-cards/dah-sing-bank
# 36768                                www.moneysmart.hk/zh-hk/credit-cards/bank-of-china
# 36938                      www.moneysmart.hk/zh-hk/credit-cards/china-construction-bank
# 37020                                             www.moneysmart.hk/en/credit-cards/bea
# 37147                         www.moneysmart.hk/en/personal-loan/bank-of-communications
# 37182                             www.moneysmart.hk/en/credit-cards/aeon-credit-service
# 40379       www.moneysmart.hk/zh-hk/credit-cards/citic-bank-international/welcome-offer
# 40420                         www.moneysmart.hk/en/credit-cards/china-construction-bank
# 40862      www.moneysmart.hk/zh-hk/credit-cards/hang-seng-bank/travel-overseas-spending
# 40863                     www.moneysmart.hk/zh-hk/credit-cards/travel-overseas-spending
# 40980                    www.moneysmart.hk/en/credit-cards/bea/travel-overseas-spending
# 41006                          www.moneysmart.hk/zh-hk/credit-cards/aeon-credit-service
# 41079                               www.moneysmart.hk/zh-hk/credit-cards/hang-seng-bank
# 41329                        www.moneysmart.hk/en/credit-cards/citic-bank-international
# 41408                                  www.moneysmart.hk/en/credit-cards/hang-seng-bank
# 41461                                  www.moneysmart.hk/zh-hk/personal-loan/ua-finance
# 41466                                        www.moneysmart.hk/en/personal-loan/promise
# 41895                                www.moneysmart.sg/maid-insurance/liberty-insurance
# 41909                                              www.moneysmart.sg/maid-insurance/tiq
# 41979                                      www.moneysmart.hk/zh-hk/travel-insurance/axa
# 41981                                   www.moneysmart.hk/zh-hk/travel-insurance/zurich
# 42001                                      www.moneysmart.hk/zh-hk/travel-insurance/dbs
# 42068                                  www.moneysmart.sg/credit-cards/hsbc/0-instalment
# 42095                                  www.moneysmart.sg/credit-cards/posb/0-instalment
# 42334                                www.moneysmart.hk/zh-hk/credit-cards/icbc/unionpay
# 42343                              www.moneysmart.sg/credit-cards/dbs/buffet-promotions
# 42347                             www.moneysmart.sg/credit-cards/posb/buffet-promotions
# 42366                             www.moneysmart.sg/credit-cards/cimb/buffet-promotions
# ...                                                                                 ...
# 46200             www.moneysmart.hk/zh-hk/credit-cards/hang-seng-bank/octopus-card-aavs
# 46380                              www.moneysmart.hk/zh-hk/personal-loan/hang-seng-bank
# 46386                        www.moneysmart.hk/en/personal-loan/china-construction-bank
# 46387                                 www.moneysmart.hk/en/personal-loan/hang-seng-bank
# 46446                            www.moneysmart.hk/en/personal-loan/aeon-credit-service
# 46563                                    www.moneysmart.hk/en/personal-loan/primecredit
# 46833                                       www-new.moneysmart.hk/en/personal-loan/hsbc
# 46939                                            www.moneysmart.sg/maid-insurance/sompo
# 47014                                  www.moneysmart.hk/zh-hk/travel-insurance/liberty
# 47027                                         www.moneysmart.hk/en/travel-insurance/dbs
# 47031                                   www.moneysmart.hk/en/credit-cards/icbc/unionpay
# 47035                                      www.moneysmart.hk/zh-hk/travel-insurance/fwd
# 47098                                   www.moneysmart.sg/credit-cards/dbs/0-instalment
# 47106                                   www.moneysmart.sg/credit-cards/uob/0-instalment
# 47350                www.moneysmart.hk/zh-hk/credit-cards/hsbc/travel-overseas-spending
# 47351            www.moneysmart.hk/zh-hk/credit-cards/citibank/travel-overseas-spending
# 47352                                 www.moneysmart.hk/zh-hk/credit-cards/dbs/unionpay
# 47353  www.moneysmart.hk/zh-hk/credit-cards/standard-chartered/travel-overseas-spending
# 47354                            www.moneysmart.hk/zh-hk/credit-cards/dbs/welcome-offer
# 47368                                  www.moneysmart.sg/credit-cards/buffet-promotions
# 47384                                                www.moneysmart.sg/cancer-insurance
# 47468                   www.moneysmart.hk/en/credit-cards/hsbc/travel-overseas-spending
# 47490                                        www.moneysmart.hk/zh-hk/personal-loan/hsbc
# 47491                     www.moneysmart.hk/zh-hk/personal-loan/china-construction-bank
# 47494                              www.moneysmart.sg/credit-cards/boc/buffet-promotions
# 47498                                         www.moneysmart.hk/zh-hk/personal-loan/dbs
# 47502                               www.moneysmart.hk/zh-hk/personal-loan/bank-of-china
# 47596                              www.moneysmart.hk/zh-hk/credit-cards/digital-wallets
# 47606                                       www.moneysmart.hk/zh-hk/home-insurance/msig
# 47686                          www.moneysmart.sg/credit-cards/revolut/buffet-promotions
#
#       page_type page_sub_type  product_category_id  product_id  provider_id  \
# 2674    Unknown          None                  NaN         NaN          NaN
# 35659   Unknown          None                  NaN         NaN          NaN
# 36721   Unknown          None                  NaN         NaN          NaN
# 36768   Unknown          None                  NaN         NaN          NaN
# 36938   Unknown          None                  NaN         NaN          NaN
# 37020   Unknown          None                  NaN         NaN          NaN
# 37147   Unknown          None                296.0         NaN          NaN
# 37182   Unknown          None                  NaN         NaN          NaN
# 40379   Unknown          None                  NaN         NaN          NaN
# 40420   Unknown          None                  NaN         NaN          NaN
# 40862   Unknown          None                  NaN         NaN          NaN
# 40863   Unknown          None                  NaN         NaN          NaN
# 40980   Unknown          None                  NaN         NaN          NaN
# 41006   Unknown          None                  NaN         NaN          NaN
# 41079   Unknown          None                  NaN         NaN          NaN
# 41329   Unknown          None                  NaN         NaN          NaN
# 41408   Unknown          None                  NaN         NaN          NaN
# 41461   Unknown          None                296.0         NaN          NaN
# 41466   Unknown          None                296.0         NaN          NaN
# 41895   Unknown          None                  NaN         NaN          NaN
# 41909   Unknown          None                  NaN         NaN          NaN
# 41979   Unknown          None                  NaN         NaN          NaN
# 41981   Unknown          None                  NaN         NaN          NaN
# 42001   Unknown          None                  NaN         NaN          NaN
# 42068   Unknown          None                  NaN         NaN          NaN
# 42095   Unknown          None                  NaN         NaN          NaN
# 42334   Unknown          None                  NaN         NaN      62233.0
# 42343   Unknown          None                  NaN         NaN        105.0
# 42347   Unknown          None                  NaN         NaN        109.0
# 42366   Unknown          None                  NaN         NaN          NaN
# ...         ...           ...                  ...         ...          ...
# 46200   Unknown          None                  NaN         NaN      62265.0
# 46380   Unknown          None                296.0         NaN          NaN
# 46386   Unknown          None                296.0         NaN          NaN
# 46387   Unknown          None                296.0         NaN          NaN
# 46446   Unknown          None                296.0         NaN          NaN
# 46563   Unknown          None                296.0         NaN          NaN
# 46833   Unknown          None                  NaN         NaN          NaN
# 46939   Unknown          None                  NaN         NaN          NaN
# 47014   Unknown          None                  NaN         NaN          NaN
# 47027   Unknown          None                  NaN         NaN          NaN
# 47031   Unknown          None                  NaN         NaN          NaN
# 47035   Unknown          None                  NaN         NaN          NaN
# 47098   Unknown          None                  NaN         NaN          NaN
# 47106   Unknown          None                  NaN         NaN          NaN
# 47350   Unknown          None                  NaN         NaN      45120.0
# 47351   Unknown          None                  NaN         NaN      62209.0
# 47352   Unknown          None                  NaN         NaN      45168.0
# 47353   Unknown          None                  NaN         NaN      45682.0
# 47354   Unknown          None                  NaN         NaN      45168.0
# 47368   Unknown          None                  NaN       408.0        104.0
# 47384   Unknown          None                  NaN         NaN          NaN
# 47468   Unknown          None                  NaN         NaN      57319.0
# 47490   Unknown          None                  NaN         NaN      56823.0
# 47491   Unknown          None                  NaN         NaN      45620.0
# 47494   Unknown          None                  NaN         NaN        112.0
# 47498   Unknown          None                  NaN         NaN      45196.0
# 47502   Unknown          None                  NaN         NaN      57287.0
# 47596   Unknown          None                  NaN         NaN          NaN
# 47606   Unknown          None                  NaN         NaN      46318.0
# 47686   Unknown          None                  NaN         NaN          NaN
#
#       page_type_jamie  \
# 2674             shop
# 35659            shop
# 36721            shop
# 36768            shop
# 36938            shop
# 37020            shop
# 37147            shop
# 37182            shop
# 40379            shop
# 40420            shop
# 40862            shop
# 40863            shop
# 40980            shop
# 41006            shop
# 41079            shop
# 41329            shop
# 41408            shop
# 41461            shop
# 41466            shop
# 41895            shop
# 41909            shop
# 41979            shop
# 41981            shop
# 42001            shop
# 42068            shop
# 42095            shop
# 42334            shop
# 42343            shop
# 42347            shop
# 42366            shop
# ...               ...
# 46200            shop
# 46380            shop
# 46386            shop
# 46387            shop
# 46446            shop
# 46563            shop
# 46833            shop
# 46939            shop
# 47014            shop
# 47027            shop
# 47031            shop
# 47035            shop
# 47098            shop
# 47106            shop
# 47350            shop
# 47351            shop
# 47352            shop
# 47353            shop
# 47354            shop
# 47368            shop
# 47384            shop
# 47468            shop
# 47490            shop
# 47491            shop
# 47494            shop
# 47498            shop
# 47502            shop
# 47596            shop
# 47606            shop
# 47686            shop
#
#                                                                            dim_page_url  \
# 2674                                              www.moneysmart.sg/savings-account/rhb
# 35659                      www.moneysmart.sg/debt-consolidation-plan/standard-chartered
# 36721                                www.moneysmart.hk/zh-hk/credit-cards/dah-sing-bank
# 36768                                www.moneysmart.hk/zh-hk/credit-cards/bank-of-china
# 36938                      www.moneysmart.hk/zh-hk/credit-cards/china-construction-bank
# 37020                                             www.moneysmart.hk/en/credit-cards/bea
# 37147                         www.moneysmart.hk/en/personal-loan/bank-of-communications
# 37182                             www.moneysmart.hk/en/credit-cards/aeon-credit-service
# 40379       www.moneysmart.hk/zh-hk/credit-cards/citic-bank-international/welcome-offer
# 40420                         www.moneysmart.hk/en/credit-cards/china-construction-bank
# 40862      www.moneysmart.hk/zh-hk/credit-cards/hang-seng-bank/travel-overseas-spending
# 40863                     www.moneysmart.hk/zh-hk/credit-cards/travel-overseas-spending
# 40980                    www.moneysmart.hk/en/credit-cards/bea/travel-overseas-spending
# 41006                          www.moneysmart.hk/zh-hk/credit-cards/aeon-credit-service
# 41079                               www.moneysmart.hk/zh-hk/credit-cards/hang-seng-bank
# 41329                        www.moneysmart.hk/en/credit-cards/citic-bank-international
# 41408                                  www.moneysmart.hk/en/credit-cards/hang-seng-bank
# 41461                                  www.moneysmart.hk/zh-hk/personal-loan/ua-finance
# 41466                                        www.moneysmart.hk/en/personal-loan/promise
# 41895                                www.moneysmart.sg/maid-insurance/liberty-insurance
# 41909                                              www.moneysmart.sg/maid-insurance/tiq
# 41979                                      www.moneysmart.hk/zh-hk/travel-insurance/axa
# 41981                                   www.moneysmart.hk/zh-hk/travel-insurance/zurich
# 42001                                      www.moneysmart.hk/zh-hk/travel-insurance/dbs
# 42068                                  www.moneysmart.sg/credit-cards/hsbc/0-instalment
# 42095                                  www.moneysmart.sg/credit-cards/posb/0-instalment
# 42334                                www.moneysmart.hk/zh-hk/credit-cards/icbc/unionpay
# 42343                              www.moneysmart.sg/credit-cards/dbs/buffet-promotions
# 42347                             www.moneysmart.sg/credit-cards/posb/buffet-promotions
# 42366                             www.moneysmart.sg/credit-cards/cimb/buffet-promotions
# ...                                                                                 ...
# 46200             www.moneysmart.hk/zh-hk/credit-cards/hang-seng-bank/octopus-card-aavs
# 46380                              www.moneysmart.hk/zh-hk/personal-loan/hang-seng-bank
# 46386                        www.moneysmart.hk/en/personal-loan/china-construction-bank
# 46387                                 www.moneysmart.hk/en/personal-loan/hang-seng-bank
# 46446                            www.moneysmart.hk/en/personal-loan/aeon-credit-service
# 46563                                    www.moneysmart.hk/en/personal-loan/primecredit
# 46833                                       www-new.moneysmart.hk/en/personal-loan/hsbc
# 46939                                            www.moneysmart.sg/maid-insurance/sompo
# 47014                                  www.moneysmart.hk/zh-hk/travel-insurance/liberty
# 47027                                         www.moneysmart.hk/en/travel-insurance/dbs
# 47031                                   www.moneysmart.hk/en/credit-cards/icbc/unionpay
# 47035                                      www.moneysmart.hk/zh-hk/travel-insurance/fwd
# 47098                                   www.moneysmart.sg/credit-cards/dbs/0-instalment
# 47106                                   www.moneysmart.sg/credit-cards/uob/0-instalment
# 47350                www.moneysmart.hk/zh-hk/credit-cards/hsbc/travel-overseas-spending
# 47351            www.moneysmart.hk/zh-hk/credit-cards/citibank/travel-overseas-spending
# 47352                                 www.moneysmart.hk/zh-hk/credit-cards/dbs/unionpay
# 47353  www.moneysmart.hk/zh-hk/credit-cards/standard-chartered/travel-overseas-spending
# 47354                            www.moneysmart.hk/zh-hk/credit-cards/dbs/welcome-offer
# 47368                                  www.moneysmart.sg/credit-cards/buffet-promotions
# 47384                                                www.moneysmart.sg/cancer-insurance
# 47468                   www.moneysmart.hk/en/credit-cards/hsbc/travel-overseas-spending
# 47490                                        www.moneysmart.hk/zh-hk/personal-loan/hsbc
# 47491                     www.moneysmart.hk/zh-hk/personal-loan/china-construction-bank
# 47494                              www.moneysmart.sg/credit-cards/boc/buffet-promotions
# 47498                                         www.moneysmart.hk/zh-hk/personal-loan/dbs
# 47502                               www.moneysmart.hk/zh-hk/personal-loan/bank-of-china
# 47596                              www.moneysmart.hk/zh-hk/credit-cards/digital-wallets
# 47606                                       www.moneysmart.hk/zh-hk/home-insurance/msig
# 47686                          www.moneysmart.sg/credit-cards/revolut/buffet-promotions
#
#        event_count_athena page_type_from_events
# 2674                  2.0       product-listing
# 35659                 1.0       product-listing
# 36721                 6.0       product-listing
# 36768               133.0       product-listing
# 36938                12.0       product-listing
# 37020                 5.0       product-listing
# 37147                 2.0       product-listing
# 37182                 8.0       product-listing
# 40379                 1.0       product-listing
# 40420                 4.0       product-listing
# 40862                10.0       product-listing
# 40863                19.0       product-listing
# 40980                 2.0       product-listing
# 41006                 6.0       product-listing
# 41079               108.0       product-listing
# 41329                 4.0       product-listing
# 41408                15.0       product-listing
# 41461                14.0       product-listing
# 41466                 3.0       product-listing
# 41895                 1.0       product-listing
# 41909                 5.0       product-listing
# 41979                 2.0       product-listing
# 41981                 3.0       product-listing
# 42001                 2.0       product-listing
# 42068                 8.0       product-listing
# 42095                 1.0       product-listing
# 42334                 8.0       product-listing
# 42343                 1.0       product-listing
# 42347                 1.0       product-listing
# 42366                 1.0       product-listing
# ...                   ...                   ...
# 46200                 1.0       product-listing
# 46380                10.0       product-listing
# 46386                 2.0       product-listing
# 46387                 3.0       product-listing
# 46446                 2.0       product-listing
# 46563                 2.0       product-listing
# 46833                 2.0       product-listing
# 46939                 2.0       product-listing
# 47014                 2.0       product-listing
# 47027                 1.0       product-listing
# 47031                 1.0       product-listing
# 47035                 2.0       product-listing
# 47098                 7.0       product-listing
# 47106                 3.0       product-listing
# 47350                 1.0       product-listing
# 47351                 2.0       product-listing
# 47352                 1.0       product-listing
# 47353                 1.0       product-listing
# 47354                 3.0       product-listing
# 47368                43.0       product-listing
# 47384                31.0       product-listing
# 47468                 1.0       product-listing
# 47490                29.0       product-listing
# 47491                 2.0       product-listing
# 47494                 2.0       product-listing
# 47498                 7.0       product-listing
# 47502                 3.0       product-listing
# 47596                19.0       product-listing
# 47606                 3.0       product-listing
# 47686                 1.0       product-listing
#
# [120 rows x 11 columns]

# %%
ptc[ptc.page_type_jamie=="blog_home_page"]
# Out:
#        page_id             page_url  page_type page_sub_type  \
# 2373   1015130   blog.moneysmart.hk  blog_page          blog
# 13258   518231   blog.moneysmart.sg  blog_page          blog
# 29677  2965738  blog3.moneysmart.hk  blog_page          blog
# 39658  2964624  blog3.moneysmart.sg  blog_page          blog
#
#        product_category_id  product_id  provider_id page_type_jamie  \
# 2373                   NaN         NaN          NaN  blog_home_page
# 13258                  NaN         NaN          NaN  blog_home_page
# 29677                  NaN         NaN          NaN  blog_home_page
# 39658                  NaN         NaN          NaN  blog_home_page
#
#               dim_page_url  event_count_athena page_type_from_events
# 2373    blog.moneysmart.hk               270.0                  home
# 13258   blog.moneysmart.sg              3105.0                 other
# 29677                  NaN                 NaN                   NaN
# 39658  blog3.moneysmart.sg                 8.0

# %%
ptc[(ptc.page_type_jamie=="home_page") & (ptc.event_count_athena>0)]
# Out:
#        page_id                  page_url   page_type page_sub_type  \
# 342     549778       learn.moneysmart.sg  learn_page         learn
# 29259  2615872  blog-admin.moneysmart.sg   blog_page          blog
# 37822   521077         www.moneysmart.sg     Unknown          None
#
#        product_category_id  product_id  provider_id page_type_jamie  \
# 342                    NaN         NaN          NaN       home_page
# 29259                  NaN         NaN          NaN       home_page
# 37822                  NaN         NaN          NaN       home_page
#
#                    dim_page_url  event_count_athena page_type_from_events
# 342         learn.moneysmart.sg                39.0
# 29259  blog-admin.moneysmart.sg                 6.0                  home
# 37822         www.moneysmart.sg              2315.0

# %%
ptc[(ptc.page_type_from_events=="category") & (ptc.page_type_jamie=="blog_article")].head(20)
# Out:
# Empty DataFrame
# Columns: [page_id, page_url, page_type, page_sub_type, product_category_id, product_id, provider_id, page_type_jamie, dim_page_url, event_count_athena, page_type_from_events]
# Index: []

# %% [markdown]
# ### Trying to make the best page_type of some so-so options

# %%
# This is a bit hacky and liable to break
# It also takes a bit of time to run -> could optimise by running as a mapping on the summary, but whatever.

def _merge_page_types(x):
    j_type = x.page_type_jamie
    if "blog" in j_type:
        page_type = "blog"
        page_sub_type = j_type
    elif j_type in ["lps", "unbounce", "trend", "calculator"]:
        page_type = "landing"
        page_sub_type = j_type
    elif j_type == "iss":
        page_type = "interstitial"
        page_sub_type = x.page_sub_type
    elif j_type == "embed":
        page_type = "embed"
        page_sub_type = "unknown"
    elif j_type == "shop":
        if x.page_type=="listing" or x.page_type_from_events=="product-listing":
            page_type = "listing"
            if x.page_sub_type in ["category_listing", "channel_listing", "provider_listing"]:
                page_sub_type = x.page_sub_type
            else:
                page_sub_type = "unknown"
        elif x.page_type_from_events == "product-details" or x.page_sub_type =="product-details":
            page_type="product_details"
            page_sub_type="unknown"
        elif x.page_type == "Unknown" and bool(x.page_type_from_events) and x.page_type_from_events!=np.NaN:
            page_type = "misc_shop_a"
            page_sub_type = x.page_type_from_events
        
        else:
            page_type = "misc_shop"
            page_sub_type = "unknown"
    else:
        page_type = j_type
        page_sub_type = "unknown"
    return pd.Series([page_type, page_sub_type], index=['page_type_merged', 'page_sub_type_merged'])
        

page_type_merged_col = ptc.apply(_merge_page_types, axis=1)

# %%
pages_types_merged_dev = pages_types_combined.merge(page_type_merged_col, how="left", left_index=True, right_index=True)

# %%
pages_types_merged_dev.groupby(['page_type_merged', 'page_sub_type_merged', "page_type", "page_sub_type", "page_type_jamie", "page_type_from_events"])\
.agg({"page_id":"count","event_count_athena":"sum"}).reset_index().rename(columns={"page_id":"page_count"})
# Out:
#    page_type_merged         page_sub_type_merged          page_type  \
# 0              blog           blog_category_page          blog_page
# 1              blog           blog_category_page          blog_page
# 2              blog       blog_category_tag_page          blog_page
# 3              blog       blog_category_tag_page          blog_page
# 4              blog       blog_category_tag_page          blog_page
# 5              blog       blog_category_tag_page          blog_page
# 6              blog       blog_category_tag_page          blog_page
# 7              blog       blog_category_tag_page          blog_page
# 8              blog       blog_category_tag_page          blog_page
# 9              blog               blog_home_page          blog_page
# 10             blog               blog_home_page          blog_page
# 11             blog               blog_home_page          blog_page
# 12             blog                blog_tag_page          blog_page
# 13            embed                      unknown            Unknown
# 14            embed                      unknown            Unknown
# 15        home_page                      unknown            Unknown
# 16        home_page                      unknown          blog_page
# 17        home_page                      unknown         learn_page
# 18     interstitial                        apply  interstitial_page
# 19     interstitial                     redirect  interstitial_page
# 20     interstitial                     redirect  interstitial_page
# 21          landing                   calculator            Unknown
# 22          landing                          lps            Unknown
# 23          landing                          lps            Unknown
# 24          landing                        trend            Unknown
# 25          landing                     unbounce            Unknown
# 26          landing                     unbounce            listing
# 27            learn                      unknown         learn_page
# 28          listing             category_listing            listing
# 29          listing              channel_listing            listing
# 30          listing              channel_listing            listing
# 31          listing             provider_listing            listing
# 32          listing             provider_listing            listing
# 33          listing                      unknown            Unknown
# 34          listing                      unknown            details
# 35        misc_shop                      unknown            Unknown
# 36        misc_shop                      unknown          blog_page
# 37        misc_shop                      unknown          blog_page
# 38        misc_shop                      unknown          form_page
# 39        misc_shop                      unknown  interstitial_page
# 40        misc_shop                      unknown     thank_you_page
# 41      misc_shop_a         claim-status-tracker            Unknown
# 42      misc_shop_a  claim-status-tracker-result            Unknown
# 43      misc_shop_a   contact-us-general-enquiry            Unknown
# 44      misc_shop_a                          lps            Unknown
# 45  product_details                      unknown            Unknown
# 46  product_details                      unknown            details
#
#        page_sub_type         page_type_jamie        page_type_from_events  \
# 0               blog      blog_category_page
# 1               blog      blog_category_page                     category
# 2               blog  blog_category_tag_page
# 3               blog  blog_category_tag_page                      article
# 4               blog  blog_category_tag_page         blog-article-details
# 5               blog  blog_category_tag_page                     category
# 6               blog  blog_category_tag_page                         home
# 7               blog  blog_category_tag_page                        other
# 8               blog  blog_category_tag_page                          tag
# 9               blog          blog_home_page
# 10              blog          blog_home_page                         home
# 11              blog          blog_home_page                        other
# 12              blog           blog_tag_page
# 13              None                   embed
# 14              None                   embed               blog-post-page
# 15              None               home_page
# 16              blog               home_page                         home
# 17             learn               home_page
# 18             apply                     iss
# 19          redirect                     iss
# 20          redirect                     iss            interstitial-page
# 21              None              calculator
# 22              None                     lps
# 23              None                     lps                          lps
# 24              None                   trend
# 25              None                unbounce
# 26  provider_listing                unbounce
# 27             learn                   learn
# 28  category_listing                    shop              product-listing
# 29   channel_listing                    shop
# 30   channel_listing                    shop              product-listing
# 31  provider_listing                    shop
# 32  provider_listing                    shop              product-listing
# 33              None                    shop              product-listing
# 34   product_details                    shop              product-listing
# 35              None                    shop
# 36              blog                    shop                      article
# 37              blog                    shop         blog-article-details
# 38              form                    shop
# 39              site                    shop
# 40         thank_you                    shop
# 41              None                    shop         claim-status-tracker
# 42              None                    shop  claim-status-tracker-result
# 43              None                    shop   contact-us-general-enquiry
# 44              None                    shop                          lps
# 45              None                    shop              product-details
# 46   product_details                    shop              product-details
#
#     page_count  event_count_athena
# 0            3                 3.0
# 1           35               810.0
# 2          204             33832.0
# 3         2318            298821.0
# 4          183            174931.0
# 5           48              1207.0
# 6            3                 4.0
# 7           63               442.0
# 8           41               306.0
# 9            1                 8.0
# 10           1               270.0
# 11           1              3105.0
# 12           4                 4.0
# 13          11              2747.0
# 14          92            212794.0
# 15           1              2315.0
# 16           1                 6.0
# 17           1                39.0
# 18          59               409.0
# 19          39                92.0
# 20         165              5141.0
# 21           9              2675.0
# 22          80              1416.0
# 23          61              2805.0
# 24           3               820.0
# 25          48              1879.0
# 26           1                 2.0
# 27          62               351.0
# 28         232              7486.0
# 29          14              3084.0
# 30          60             11081.0
# 31          24               155.0
# 32          57              2704.0
# 33         120              1511.0
# 34           2                27.0
# 35         142             12150.0
# 36           2                 4.0
# 37           2                12.0
# 38           1                71.0
# 39           2                32.0
# 40           3                58.0
# 41           1               178.0
# 42           1                23.0
# 43           1               110.0
# 44           1                14.0
# 45         162              3658.0
# 46         135              7316.0

# %%
pages_types_merged_dev[(pages_types_merged_dev.page_type_merged=="misc_shop") & (pages_types_merged_dev.page_sub_type_merged=="unknown")].sort_values("event_count_athena", ascending = False).head(20)
# Out:
#        page_id                                                  page_url  \
# 20690   901598                     www.moneysmart.sg/refinancing/compare
# 8146    679337                       www.moneysmart.sg/home-loan/compare
# 17928   902232               www.moneysmart.sg/refinancing/compare/loans
# 10945   852846           www.moneysmart.sg/car-insurance/wizard/register
# 5064    517603                    www.moneysmart.sg/car-insurance/wizard
# 42905  1524742  www.moneysmart.hk/zh-hk/mortgage/property-valuation-tool
# 37073  1536292                          www.moneysmart.hk/zh-hk/mortgage
# 40490  1011194                                   www.moneysmart.hk/zh-hk
# 6631    826200            www.moneysmart.sg/car-insurance/wizard/results
# 37341   678568                 www.moneysmart.sg/home-loan/compare/loans
# 21480   902997            www.moneysmart.sg/refinancing/compare/register
# 36933  1793175                www.moneysmart.hk/zh-hk/mortgage/refinance
# 43121  1794201             www.moneysmart.hk/zh-hk/mortgage/new-purchase
# 34396   527870                                www.moneysmart.sg/mortgage
# 5839   1436001      www.moneysmart.sg/refinancing/refinancing-calculator
# 3424    678848              www.moneysmart.sg/home-loan/compare/register
# 45941  1276506        www.moneysmart.sg/car-insurance/fwd/driver-details
# 43064  1013889                                      www.moneysmart.hk/en
# 25974   517761                               www.moneysmart.sg/insurance
# 26084   519310                           www.moneysmart.sg/rewards/claim
#
#       page_type page_sub_type  product_category_id  product_id  provider_id  \
# 20690   Unknown          None                  NaN         NaN          NaN
# 8146    Unknown          None                  NaN         NaN          NaN
# 17928   Unknown          None                  NaN         NaN          NaN
# 10945   Unknown          None                  NaN         NaN          NaN
# 5064    Unknown          None                  NaN         NaN          NaN
# 42905   Unknown          None                  NaN         NaN          NaN
# 37073   Unknown          None                  NaN         NaN          NaN
# 40490   Unknown          None                  NaN         NaN          NaN
# 6631    Unknown          None                  NaN         NaN          NaN
# 37341   Unknown          None                  NaN         NaN          NaN
# 21480   Unknown          None                  NaN         NaN          NaN
# 36933   Unknown          None                  NaN         NaN          NaN
# 43121   Unknown          None                  NaN         NaN          NaN
# 34396   Unknown          None                  NaN         NaN          NaN
# 5839    Unknown          None                  NaN         NaN          NaN
# 3424    Unknown          None                  NaN         NaN          NaN
# 45941   Unknown          None                  NaN         NaN      46194.0
# 43064   Unknown          None                  NaN         NaN          NaN
# 25974   Unknown          None                  NaN         NaN          NaN
# 26084   Unknown          None                  NaN         NaN          NaN
#
#       page_type_jamie  \
# 20690            shop
# 8146             shop
# 17928            shop
# 10945            shop
# 5064             shop
# 42905            shop
# 37073            shop
# 40490            shop
# 6631             shop
# 37341            shop
# 21480            shop
# 36933            shop
# 43121            shop
# 34396            shop
# 5839             shop
# 3424             shop
# 45941            shop
# 43064            shop
# 25974            shop
# 26084            shop
#
#                                                    dim_page_url  \
# 20690                     www.moneysmart.sg/refinancing/compare
# 8146                        www.moneysmart.sg/home-loan/compare
# 17928               www.moneysmart.sg/refinancing/compare/loans
# 10945           www.moneysmart.sg/car-insurance/wizard/register
# 5064                     www.moneysmart.sg/car-insurance/wizard
# 42905  www.moneysmart.hk/zh-hk/mortgage/property-valuation-tool
# 37073                          www.moneysmart.hk/zh-hk/mortgage
# 40490                                   www.moneysmart.hk/zh-hk
# 6631             www.moneysmart.sg/car-insurance/wizard/results
# 37341                 www.moneysmart.sg/home-loan/compare/loans
# 21480            www.moneysmart.sg/refinancing/compare/register
# 36933                www.moneysmart.hk/zh-hk/mortgage/refinance
# 43121             www.moneysmart.hk/zh-hk/mortgage/new-purchase
# 34396                                www.moneysmart.sg/mortgage
# 5839       www.moneysmart.sg/refinancing/refinancing-calculator
# 3424               www.moneysmart.sg/home-loan/compare/register
# 45941        www.moneysmart.sg/car-insurance/fwd/driver-details
# 43064                                      www.moneysmart.hk/en
# 25974                               www.moneysmart.sg/insurance
# 26084                           www.moneysmart.sg/rewards/claim
#
#        event_count_athena page_type_from_events page_type_merged  \
# 20690              3668.0                              misc_shop
# 8146               1620.0                              misc_shop
# 17928               950.0                              misc_shop
# 10945               682.0                              misc_shop
# 5064                651.0                              misc_shop
# 42905               481.0                              misc_shop
# 37073               480.0                              misc_shop
# 40490               470.0                              misc_shop
# 6631                379.0                              misc_shop
# 37341               333.0                              misc_shop
# 21480               295.0                              misc_shop
# 36933               270.0                              misc_shop
# 43121               165.0                              misc_shop
# 34396               160.0                              misc_shop
# 5839                115.0                              misc_shop
# 3424                105.0                              misc_shop
# 45941                89.0                              misc_shop
# 43064                80.0                              misc_shop
# 25974                76.0                              misc_shop
# 26084                73.0                              misc_shop
#
#       page_sub_type_merged
# 20690              unknown
# 8146               unknown
# 17928              unknown
# 10945              unknown
# 5064               unknown
# 42905              unknown
# 37073              unknown
# 40490              unknown
# 6631               unknown
# 37341              unknown
# 21480              unknown
# 36933              unknown
# 43121              unknown
# 34396              unknown
# 5839               unknown
# 3424               unknown
# 45941              unknown
# 43064              unknown
# 25974              unknown
# 26084              unknown

# %%
pages_types_merged = pages_types_merged_dev[["page_id", "page_url", "page_type_merged", "page_sub_type_merged","event_count_athena"]].rename(columns={"page_type_merged": "page_type", "page_sub_type_merged":"page_sub_type"})
canonical_urls_col = pages_types_merged.apply(lambda x: data_parsing.get_canonical_url("https://"+x.page_url), axis=1)
pages_types_merged["canonical_url"] = canonical_urls_col

# %%
len(pages_types_merged)
# Out:
# 47691

# %%
len(pages)
# Out:
# 47691

# %%
# we should have fewer grouping by canonical as it removes the AB test urls
len(pages_types_merged.groupby(["canonical_url"]))
# Out:
# 40522

# %%
len(pages_types_merged.groupby(["canonical_url", "page_type", "page_sub_type"]))
# Out:
# 41347

# %%
# TODO: >>>>>> there's a mismatch here.  Probably want to do a group by, max on it to merge them together and then join again with the non-canonical... but should really investigate the origin.
# See below, it looks like a remnant of AB testing falcon

# %%
issues = pages_types_merged.groupby(["canonical_url", "page_type", "page_sub_type"]).count().groupby(["canonical_url"]).size()

# %%
issues[issues.values>1]
# Out:
# canonical_url
# www.moneysmart.hk/en/credit-cards/american-express-platinum-credit-card                            2
# www.moneysmart.hk/en/credit-cards/icbc/unionpay                                                    2
# www.moneysmart.hk/en/personal-loan/hsbc                                                            2
# www.moneysmart.hk/zh-hk/credit-cards/american-express-platinum-credit-card                         2
# www.moneysmart.hk/zh-hk/credit-cards/bank-of-china                                                 2
# www.moneysmart.hk/zh-hk/credit-cards/dbs/unionpay                                                  2
# www.moneysmart.hk/zh-hk/credit-cards/dbs/welcome-offer                                             2
# www.moneysmart.hk/zh-hk/credit-cards/icbc/unionpay                                                 2
# www.moneysmart.hk/zh-hk/credit-cards/icbc/welcome-offer                                            2
# www.moneysmart.sg/credit-cards/american-express-platinum-credit-card                               2
# www.moneysmart.sg/credit-cards/american-express-singapore-airlines-krisflyer-ascend-credit-card    2
# www.moneysmart.sg/credit-cards/american-express-singapore-airlines-krisflyer-credit-card           2
# www.moneysmart.sg/credit-cards/american-express-the-platinum-card                                  2
# www.moneysmart.sg/credit-cards/american-express-true-cashback-card                                 2
# www.moneysmart.sg/credit-cards/bank-of-china-family-card                                           2
# www.moneysmart.sg/credit-cards/bank-of-china-qoo10-world-mastercard                                2
# www.moneysmart.sg/credit-cards/bank-of-china-sheng-siong-card                                      2
# www.moneysmart.sg/credit-cards/bank-of-china-zaobao-credit-card                                    2
# www.moneysmart.sg/credit-cards/boc-elite-miles-world-mastercard                                    2
# www.moneysmart.sg/credit-cards/cimb-platinum-mastercard                                            2
# www.moneysmart.sg/credit-cards/cimb-visa-infinite                                                  2
# www.moneysmart.sg/credit-cards/cimb-visa-signature                                                 2
# www.moneysmart.sg/credit-cards/cimb-world-mastercard                                               2
# www.moneysmart.sg/credit-cards/citi-cash-back-card                                                 2
# www.moneysmart.sg/credit-cards/citi-lazada-card                                                    2
# www.moneysmart.sg/credit-cards/citi-premiermiles-card                                              2
# www.moneysmart.sg/credit-cards/citibank-rewards-card                                               2
# www.moneysmart.sg/credit-cards/citibank-smrt-platinum-visa-card                                    2
# www.moneysmart.sg/credit-cards/dbs-altitude-visa-signature-card                                    2
# www.moneysmart.sg/credit-cards/dbs-black-visa-card                                                 2
#                                                                                                   ..
# www.moneysmart.sg/credit-cards/ocbc-plus-visa-credit-card                                          2
# www.moneysmart.sg/credit-cards/ocbc-titanium-rewards-card                                          2
# www.moneysmart.sg/credit-cards/ocbc-titanium-rewards-card-blue                                     2
# www.moneysmart.sg/credit-cards/posb-everyday-card                                                  2
# www.moneysmart.sg/credit-cards/revolut-premium-debit-card                                          2
# www.moneysmart.sg/credit-cards/revolut-standard-debit-card                                         2
# www.moneysmart.sg/credit-cards/standard-chartered-platinum-credit-card                             2
# www.moneysmart.sg/credit-cards/standard-chartered-rewards                                          2
# www.moneysmart.sg/credit-cards/standard-chartered-spree-credit-card                                2
# www.moneysmart.sg/credit-cards/standard-chartered-unlimited-cashback-card                          2
# www.moneysmart.sg/credit-cards/standard-chartered-x-card                                           2
# www.moneysmart.sg/credit-cards/uob-delight-card                                                    2
# www.moneysmart.sg/credit-cards/uob-lady-s-card                                                     2
# www.moneysmart.sg/credit-cards/uob-one-card                                                        2
# www.moneysmart.sg/credit-cards/uob-preferred-platinum-visa-card                                    2
# www.moneysmart.sg/credit-cards/uob-prvi-miles-card                                                 2
# www.moneysmart.sg/credit-cards/uob-yolo                                                            2
# www.moneysmart.sg/debt-consolidation-plan                                                          2
# www.moneysmart.sg/personal-loan/citibank-quick-cash                                                2
# www.moneysmart.sg/personal-loan/citibank-quick-cash-existing-customers                             2
# www.moneysmart.sg/personal-loan/dbs-personal-loan                                                  2
# www.moneysmart.sg/personal-loan/hl-bank-personal-loan                                              2
# www.moneysmart.sg/personal-loan/hsbc-personal-loan                                                 2
# www.moneysmart.sg/personal-loan/hsbc-personal-loan-foreigners                                      2
# www.moneysmart.sg/personal-loan/ocbc-extra-cash-loan                                               2
# www.moneysmart.sg/personal-loan/posb-personal-loan                                                 2
# www.moneysmart.sg/personal-loan/scb-cashone                                                        2
# www.moneysmart.sg/personal-loan/scb-cashone-foreigners                                             2
# www.moneysmart.sg/personal-loan/uob-personal-loan                                                  2
# www.moneysmart.sg/travel-insurance/the-wise-traveller                                              2
# Length: 84, dtype: int64

# %%
pages_types_merged[pages_types_merged.canonical_url=="www.moneysmart.sg/personal-loan/scb-cashone"]
# Out:
#        page_id                                         page_url  \
# 14528   517928      www.moneysmart.sg/personal-loan/scb-cashone
# 35520  2678863  www-new.moneysmart.sg/personal-loan/scb-cashone
#
#              page_type page_sub_type  event_count_athena  \
# 14528  product_details       unknown                94.0
# 35520        misc_shop       unknown                 NaN
#
#                                      canonical_url
# 14528  www.moneysmart.sg/personal-loan/scb-cashone
# 35520  www.moneysmart.sg/personal-loan/scb-cashone

# %%
pages_types_merged.head()
# Out:
#    page_id  \
# 0  1375785
# 1  1647817
# 2  1376813
# 3  1158494
# 4  1378619
#
#                                                                                                                                                                                     page_url  \
# 0  blog.moneysmart.hk/en/mortgage/%E5%B1%85%E5%B1%8B-2019-%E4%BD%95%E6%96%87%E7%94%B0-%E5%B0%87%E8%BB%8D%E6%BE%B3-%E7%94%B3%E8%AB%8B-%E9%A6%AC%E9%9E%8D%E5%B1%B1-%E6%B7%B1%E6%B0%B4%E5%9F%97
# 1                                                                             blog.moneysmart.sg/property/private-properties-hdbs-differences/attachment/private-vs-public-housing-singapore
# 2                                                                                                                                            forum.moneysmart.sg/topic/taking-multiple-loans
# 3                                                                                                    blog.moneysmart.sg/dining/11-best-places-in-singapore-to-get-your-meat-fix-at-1-for-1/_
# 4                                                                                                                                                              www.moneysmart.sg/home%20loan
#
#      page_type           page_sub_type  event_count_athena  \
# 0         blog  blog_category_tag_page                 NaN
# 1         blog  blog_category_tag_page                 NaN
# 2    misc_shop                 unknown                 NaN
# 3         blog  blog_category_tag_page                 NaN
# 4  misc_shop_a                     NaN                 NaN
#
#                                                                                                                                                                                canonical_url
# 0  blog.moneysmart.hk/en/mortgage/%e5%b1%85%e5%b1%8b-2019-%e4%bd%95%e6%96%87%e7%94%b0-%e5%b0%87%e8%bb%8d%e6%be%b3-%e7%94%b3%e8%ab%8b-%e9%a6%ac%e9%9e%8d%e5%b1%b1-%e6%b7%b1%e6%b0%b4%e5%9f%97
# 1                                                                             blog.moneysmart.sg/property/private-properties-hdbs-differences/attachment/private-vs-public-housing-singapore
# 2                                                                                                                                            forum.moneysmart.sg/topic/taking-multiple-loans
# 3                                                                                                    blog.moneysmart.sg/dining/11-best-places-in-singapore-to-get-your-meat-fix-at-1-for-1/_
# 4                                                                                                                                                              www.moneysmart.sg/home%20loan

# %% [markdown]
# # Looking at the LeadGeneration.ClickConversion event

# %% [markdown]
# ## Getting the click event data

# %%
query = """
select  

    country_code
    , dim_page_type.page_type
    , dim_page_type.page_sub_type
    , case when page_url like '%/embed/%' then true else false end as is_embed
    , page_url
    , page_id
    , full_date
    , time
    , hour
    , minute
    , device_os
    , device_category
    , browser
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'channel', true) as channel
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'product_slug', true) as product_slug
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'product', true) as product
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'product_id', true) as product_id
    , dim_product.slug as product_from_id
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'provider_slug', true) as provider_slug
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'provider', true) as provider
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'provider_id', true) as provider_id
    , dim_provider.slug as provider_from_id
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'affiliate_category', true) as affiliate_category
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'affiliate_location', true) as affiliate_location
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'affiliate_page_type', true) as affiliate_page_type
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'affiliate_widget_type', true) as affiliate_widget_type
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'list_position', true) as list_position
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'action', true) as action
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'source', true) as source
    , dim_activity.activity_attributes
    from 
    
    -- TODO: cut down the join.s just copy / pasting
    fact_activities 
    left join dim_page on fact_activities.page_id = dim_page.page_id
    left join dim_page_type on dim_page_type.page_type_id = dim_page.page_type_id
    -- left join dim_session on fact_activities.session_id = dim_session.session_id
    left join dim_activity on fact_activities.activity_id = dim_activity.activity_id
    
    left join dim_activity_type on fact_activities.activity_type_id = dim_activity_type.activity_type_id
    left join dim_date on dim_date.date_id = fact_activities.activity_date_id
    left join dim_time on fact_activities.activity_time_id = dim_time.time_id
    left join dim_country on fact_activities.site_country_id = dim_country.country_id
    
    left join dim_browser on fact_activities.browser_id = dim_browser.browser_id -- firefox etc
    left join dim_device on fact_activities.device_id = dim_device.device_id -- device_os, device_category (desktop / mobile...)
    
    left join dim_channel on dim_channel.channel_key = json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'channel', true)
    -- only join product and provider if the slug isn't set i.e. assume that it's pre-falcon YMMV (and it's deprecated)
    left join dim_product on (dim_product.source_product_id = json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'product_id', true) 
        and coalesce(json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'product', true), '') =''
        and dim_product.channel_id = dim_channel.channel_id 
        and dim_product.country_id = dim_country.country_id) 
    left join dim_provider on (
        dim_provider.source_provider_id = json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'provider_id', true) 
        and coalesce(json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'provider', true), '') =''
        and dim_provider.channel_id = dim_channel.channel_id 
            and dim_provider.country_id = dim_country.country_id)
    

    
    where 
        dim_activity_type.activity_name = 'LeadGeneration.ClickConversion'
        and user_filter_type='external_visitor'
        and dim_date.full_date>='{from_date}'
        and dim_date.full_date<='{to_date}'
        
        
        -- NB: embeds aren't currently listed as blog pages :(
        
""".format(from_date= from_datetime.isoformat(), to_date=to_datetime.isoformat())

# %%
print(query)

# %%
query = sqlalchemy.text(query)
apply_clicks = dq.query(query)

# %%
apply_clicks.describe()

# %%
apply_clicks.head(5)

# %%
pd.set_option("display.max_colwidth", 200)
# apply_clicks[apply_clicks["page_type"].str.contains("blog")][["page_url", "provider", "provider_id", "activity_attributes"]]
for a in apply_clicks[apply_clicks["page_type"].str.contains("blog")][ "activity_attributes"].values[0].split(","): print(a)

# %%
product_provider_summary_cols = [ "page_url", "action", "page_type", "channel"]+ [z for z in apply_clicks.columns if "product" in z or "provider" in z]
affiliate_cols = [z for z in apply_clicks.columns if "affiliate" in z]

# %%
apply_clicks[product_provider_summary_cols ].head()

# %% [markdown]
# ## Issues

# %%
def format_results(df):
    def make_clickable(val):
        # target _blank to open new window
        return '<a target="_blank" href="{}">{}</a>'.format("https://"+ val, val)
    
    return df.style.format({'page_url': make_clickable})

# %% [markdown]
# ### Not having product / provider (slug) set (product_id or provider_id is deprecated)

# %%
df = apply_clicks[(apply_clicks.provider.isna()) | (apply_clicks.provider=="")][product_provider_summary_cols]
print("only first 20 shown")
format_results(df.head(20))

# %%
df2 = pd.DataFrame(df.groupby(["page_url", "page_type","channel"]).size().reset_index().sort_values(0, ascending=False))
format_results(df2)

# %% [markdown]
# ### Using product_slug or provider_slug not product / provider

# %%
apply_clicks[~(apply_clicks.provider_slug.isna() | (apply_clicks.provider_slug==""))][product_provider_summary_cols]

# %%
apply_clicks[~(apply_clicks["product_slug"].isna() | (apply_clicks["product_slug"]==""))][product_provider_summary_cols]

# %% [markdown]
# ### Not having any product or provider info

# %%
# No product info
df = apply_clicks[(apply_clicks["product"].isna() | (apply_clicks["product"]=="")) & (apply_clicks.product_id.isna() | ((apply_clicks["product_id"]=="")))][product_provider_summary_cols]
df2 = pd.DataFrame(df.groupby(["page_url", "page_type", "channel"]).size()).reset_index().sort_values(0, ascending=False).rename(columns={0:"click count"})
format_results(df2)

# %%
# No provider info
apply_clicks[(apply_clicks.provider.isna() | (apply_clicks.provider==""))][product_provider_summary_cols]

# %%
# No product or provider info, grouped by number of clicks on the page
missing_providers = apply_clicks[((apply_clicks.provider=="" ) | (apply_clicks.provider.isna())) & ((apply_clicks.provider_id=="" ) | (apply_clicks.provider_id.isna())) ][["page_url", "provider", "provider_id"]]
missing_providers_grouped = missing_providers.groupby(["page_url"]).size().reset_index() #.rename(columns={0:"click count"})
#missing_providers_grouped.sort_values("provider_id", ascending=False)
format_results(pd.DataFrame(missing_providers_grouped.sort_values(0, ascending=False)))

# %% [markdown]
# ### Embed without any info about the page that it's on

# %%
print("all of them!")

# %% [markdown]
# ### Blog page without affiliate stuff set
# Blog should have full details of e.g. where on the page it is coming from

# %%
apply_clicks.page_type.unique()

# %%
df = apply_clicks[ apply_clicks.page_type.isin(["blog_page"]) & ((apply_clicks.affiliate_category=="") | (apply_clicks.affiliate_location=="") | (apply_clicks.affiliate_page_type=="") |  (apply_clicks.affiliate_widget_type=="")\
             | (apply_clicks.affiliate_category.isna()) | (apply_clicks.affiliate_location.isna()) | (apply_clicks.affiliate_page_type.isna()) |  (apply_clicks.affiliate_widget_type.isna()))][product_provider_summary_cols + affiliate_cols]

format_results(df)

# %%
"""
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'affiliate_category', true) as affiliate_category
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'affiliate_location', true) as affiliate_location
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'affiliate_page_type', true) as affiliate_page_type
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'affiliate_widget_type', true) as affiliate_widget_type

"""

# %% [markdown]
# ### Fails to join on provider_id or product_id
#
# Note that you might expect some pre-falcon stuff in HK not to join as we didn't have the application database loaded.

# %%
# product_id is set, but product_from_id is null
df = apply_clicks[((apply_clicks["product"]=="") | apply_clicks["product"].isna()) & apply_clicks.product_id.str.isnumeric() & apply_clicks.product_from_id.isna()][product_provider_summary_cols]
format_results(df)

# %%
# provider can't be interpreted from provider_id
df = apply_clicks[((apply_clicks["provider"]=="") | apply_clicks["provider"].isna()) & apply_clicks.provider_id.str.isnumeric() & apply_clicks.provider_from_id.isna()][product_provider_summary_cols]
print(len(df))
format_results(df)

# %%
providers_channels[providers_channels.source_provider_id == 1]

# %%
providers_channels[~providers_channels.source_provider_id.isna()][providers_channels.source_provider_id>30].sort_values(["source_provider_id"])

# %% [markdown]
# ### Channels Observed (manual sense check)

# %%
apply_clicks.columns

# %%
apply_clicks.groupby(["channel"]).size().sort_index()

# %% [markdown]
# ## Listing click doesn't have index
# (not sure been implemented yet on falcon)

# %% [markdown]
# ## Trying to get something useful out of apply clicks
#
# NB don't use these numbers for reporting just yet.

# %%
def group_and_sort(df, cols_to_group_and_sort_by, sort_by_click_count = False):
    r = pd.DataFrame(df.groupby(cols_to_group_and_sort_by).size().reset_index().rename(columns={0:"num_clicks"}))
    if sort_by_click_count:
        if "country_code" in r.columns:
            r = r.sort_values(["country_code", "num_clicks"], ascending = False)
        else:
            r = r.sort_values("num_clicks", ascending = False)
    else:
        r = r.sort_values(cols_to_group_and_sort_by)
    total_clicks = >>
    >> total clicks by country
    >> do distinct anonymous_id, day
    return format_results(r) #AToW makes urls clickable

# %% [markdown]
# ### Blog apply clicks excluding embeds by where they come from
#
# AToW this won't include apply clicks from the comparison widgets in the page, but it will work for the

# %%
blog_apply_clicks = apply_clicks[apply_clicks["page_type"].str.contains("blog")]

# %%
group_and_sort(blog_apply_clicks, ["country_code", "channel", "affiliate_category"])

# %% [markdown]
# ### Blog apply clicks excluding embeds by place on page

# %%
group_and_sort(blog_apply_clicks, ["country_code","channel"]+ affiliate_cols)

# %% [markdown]
# ### Blog apply clicks excluding embeds by product and provier

# %%
group_and_sort(blog_apply_clicks, ["country_code","channel", "product", "provider"]+ affiliate_cols)

# %% [markdown]
# ### Blog apply clicks excluding embeds top articles

# %%
group_and_sort(blog_apply_clicks, ["country_code","page_url"], sort_by_click_count=True)

# %% [markdown]
# ### Comparison widget (embed) apply clicks

# %%
embed_apply_clicks = apply_clicks[apply_clicks.is_embed==True]

# %%
group_and_sort(embed_apply_clicks,["country_code","channel"]+ affiliate_cols)

# %% [markdown]
# ### Embed by location on page

# %%
group_and_sort(embed_apply_clicks, ["country_code", "affiliate_location"])

# %% [markdown]
# ### Blog apply clicks on page & embed
# NB you can't do by url this way

# %%
blog_and_embed_apply_clicks = blog_apply_clicks.append(embed_apply_clicks)

# %%
group_and_sort(blog_and_embed_apply_clicks, ["country_code","channel"]+ affiliate_cols)

# %% [markdown]
# ### Blog and embed apply clicks by product and provider

# %%
group_and_sort(blog_and_embed_apply_clicks, ["country_code","channel", "product", "provider"])

# %%
group_and_sort(blog_and_embed_apply_clicks, ["country_code","channel", "product", "provider"]+ affiliate_cols)

# %% [markdown]
# ### All clicks mobile vs desktop vs channel

# %%
group_and_sort(apply_clicks,["country_code","device_category"] )

# %%
group_and_sort(apply_clicks, ["country_code","channel", "device_category"])

# %% [markdown]
# ### All clicks by page type (and sub-type)
# NB this isn't set properly for embeds

# %%
group_and_sort(apply_clicks, ["country_code","page_type", "page_sub_type", "is_embed"])

# %% [markdown]
# ### All clicks by channel

# %%
group_and_sort(apply_clicks, ["country_code","channel"])

# %% [markdown]
# ### All clicks by channel and product

# %%
group_and_sort(apply_clicks, ["country_code","channel", "product", "provider"])

# %% [markdown]
# ### All clicks by list position
#
# List position will only apply on listing pages and blog pages where it has been set.  Won't work on PDP

# %%
group_and_sort(apply_clicks, ["country_code","channel", "page_type", "list_position"])

# %% [markdown]
# # ISS, .../apply etc pageview applies
#
# The main way that we track apply clicks is through ISS (and before that an earlier interstitial page).  NB other actions like contact form submissions aren't tracked.
#
# Expect this not to work well for mortgage and car insurance

# %% [markdown]
# # NPP

# %% [markdown]
# # More Questions
# * Where did people land from?
# * Conversion rates based on users / pageviews  / sessions
# * Is there a time delay between pageviews and applies? (across the site, across shop, across blog)?
