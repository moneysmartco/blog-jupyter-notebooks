# %% [markdown]
# # Where apply button clicks come from
#
# There's two ways to look at the data, each of which might give slightly different counts:
# * LeadGeneration.ClickConversion from the button click
# * PageView on the ISS page
# * (and also redirect completed on ISS)
#
# The button click event gives more context about where on the page the click happened, while the ISS pageview is the official definition of an action.
#
#
# Events should be defined as per https://docs.google.com/spreadsheets/d/1HICh77BoGMIat9K3NPwz3pBayJWiAr0ohAlTuv7dr80/edit#gid=1692709656, but this hasn't be implemented consistently.
#
# Of note for button clicks / LeadGeneration.ClickConversion:
# * We used to send product_id and provider_id, but with the move to Falcon that doesn't work any longer (or will provide incorrect results).  LPS in particular doesn't seem to have updated the implementation.
# * The product comparison widget in the blog currently doesn't tell us what page it is on
# * Sometimes there is no product or provider info coming through
#
#
# Other things of note:
# * LPS pages don't seem to be categorised as such in the database
#
#
# Outstanding things not necessarily covered below:
# * NPP clicks

# %%
from datetime import datetime, timedelta
import numpy as np
import pandas as pd
import sqlalchemy

from data_warehouse_querying import DataWarehouseQuery

# %% [markdown]
# # Settings

# %%
num_days_to_query = 2
to_datetime = datetime.now().date() - timedelta(days=1) #datetime(year=2020, month=3, day=1)
from_datetime = to_datetime - timedelta(days=num_days_to_query)

# %% [markdown]
# # Getting Base Data

# %%
dq = DataWarehouseQuery()
dq.connect()

# %%
products = dq.query("select * from dim_product")
# Out:
# Starting query at 2020-04-07T02:55:37.315620
# Query took 0.10

# %%
products.head()
# Out:
#    product_id                                   product_name  \
# 0       56622                       CIMB Platinum Mastercard
# 1       70784                Maybank DUO Platinum Mastercard
# 2       75681                                 OCBC 90°N Card
# 3       81857  Citibank Quick Cash (Existing Loan Customers)
# 4       93497                            OCBC ExtraCash Loan
#
#   source_product_id               sys_inserted                sys_updated  \
# 0               101 2019-07-08 19:34:51.551632 2019-07-08 19:34:51.551632
# 1               105 2019-08-16 19:34:45.935610 2019-08-16 19:34:45.935610
# 2               106 2019-08-30 19:34:23.890164 2019-08-30 19:34:23.890164
# 3                24 2019-09-16 19:35:32.751792 2019-09-16 19:35:32.751792
# 4                28 2019-10-18 20:10:55.807708 2019-10-18 20:10:55.807708
#
#    status                                               slug  language_id  \
# 0       0  cimb-platinum-mastercard-212cae7f-f5cd-4dd1-ba...            1
# 1       1                    maybank-duo-platinum-mastercard            1
# 2       0                                     ocbc-90-n-card            1
# 3       1             citibank-quick-cash-existing-customers            1
# 4       0                               ocbc-extra-cash-loan            1
#
#    channel_id  provider_id  country_id
# 0           4          102           1
# 1           4          107           1
# 2           4          108           1
# 3          16          836           1
# 4          16          833           1

# %%
providers = dq.query("select * from dim_provider")
# Out:
# Starting query at 2020-04-07T02:55:37.439415
# Query took 0.06

# %%
providers.head()
# Out:
#    provider_id            provider_name               sys_inserted  \
# 0          833                     OCBC 2019-02-19 19:32:36.488054
# 1          837  Standard Chartered Bank 2019-02-19 19:32:36.488054
# 2          100  Standard Chartered Bank 2019-01-21 19:32:53.867181
# 3          104                 Citibank 2019-01-21 19:32:53.867181
# 4          255                      AXA 2019-02-01 01:43:57.318499
#
#                  sys_updated  source_provider_id        slug  status  \
# 0 2019-02-19 19:32:36.488054                 6.0        ocbc       1
# 1 2019-02-19 19:32:36.488054                 2.0         scb       1
# 2 2019-01-21 19:32:53.867181                67.0         scb       0
# 3 2019-01-21 19:32:53.867181                56.0    citibank       1
# 4 2019-02-01 01:43:57.318499               259.0  axa-direct       1
#
#    channel_id  country_id  language_id
# 0          16           1            1
# 1          16           1            1
# 2           4           1            1
# 3           4           1            1
# 4          20           1            1

# %%
channels = dq.query("select * from dim_channel")
# Out:
# Starting query at 2020-04-07T02:55:37.519304
# Query took 0.03

# %%
channels.head()
# Out:
#    channel_id                  channel_key                    channel_name  \
# 0           3                     car-loan                        Car Loan
# 1           7             health-insurance                Health Insurance
# 2          11         international-health  International Health Insurance
# 3          15  personal-accident-insurance     Personal Accident Insurance
# 4          19              savings-account                 Saving Accounts
#
#                 sys_inserted                sys_updated
# 0 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 1 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 2 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 3 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 4 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062

# %%
providers_channels = pd.merge(providers, channels, on="channel_id", how="left")

# %%
len(providers)
# Out:
# 496

# %%
len(providers_channels)
# Out:
# 496

# %% [markdown]
# # Looking at the LeadGeneration.ClickConversion event

# %% [markdown]
# ## Getting the click event data

# %%
query = """
select  

    country_code
    , dim_page_type.page_type
    , dim_page_type.page_sub_type
    , case when page_url like '%/embed/%' then true else false end as is_embed
    , page_url
    , device_os
    , device_category
    , browser
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'channel', true) as channel
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'product_slug', true) as product_slug
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'product', true) as product
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'product_id', true) as product_id
    , dim_product.slug as product_from_id
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'provider_slug', true) as provider_slug
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'provider', true) as provider
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'provider_id', true) as provider_id
    , dim_provider.slug as provider_from_id
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'affiliate_category', true) as affiliate_category
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'affiliate_location', true) as affiliate_location
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'affiliate_page_type', true) as affiliate_page_type
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'affiliate_widget_type', true) as affiliate_widget_type
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'list_position', true) as list_position
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'action', true) as action
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'source', true) as source
    , dim_activity.activity_attributes
    from 
    
    -- TODO: cut down the join.s just copy / pasting
    fact_activities 
    left join dim_page on fact_activities.page_id = dim_page.page_id
    left join dim_page_type on dim_page_type.page_type_id = dim_page.page_type_id
    -- left join dim_session on fact_activities.session_id = dim_session.session_id
    left join dim_activity on fact_activities.activity_id = dim_activity.activity_id
    
    left join dim_activity_type on fact_activities.activity_type_id = dim_activity_type.activity_type_id
    left join dim_date on dim_date.date_id = fact_activities.activity_date_id
    -- left join dim_time on fact_activities.activity_time_id = dim_time.time_id
    left join dim_country on fact_activities.site_country_id = dim_country.country_id
    
    left join dim_browser on fact_activities.browser_id = dim_browser.browser_id -- firefox etc
    left join dim_device on fact_activities.device_id = dim_device.device_id -- device_os, device_category (desktop / mobile...)
    
    left join dim_channel on dim_channel.channel_key = json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'channel', true)
    -- only join product and provider if the slug isn't set i.e. assume that it's pre-falcon YMMV (and it's deprecated)
    left join dim_product on (dim_product.source_product_id = json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'product_id', true) 
        and coalesce(json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'product', true), '') =''
        and dim_product.channel_id = dim_channel.channel_id 
        and dim_product.country_id = dim_country.country_id) 
    left join dim_provider on (
        dim_provider.source_provider_id = json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'provider_id', true) 
        and coalesce(json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'provider', true), '') =''
        and dim_provider.channel_id = dim_channel.channel_id 
            and dim_provider.country_id = dim_country.country_id)
    

    
    where 
        dim_activity_type.activity_name = 'LeadGeneration.ClickConversion'
        
        and user_filter_type='external_visitor'
         and dim_date.full_date>='{from_date}'
            and dim_date.full_date<='{to_date}'
        
        
        -- NB: embeds aren't currently listed as blog pages :(
        
""".format(from_date= from_datetime.isoformat(), to_date=to_datetime.isoformat())

# %%
dq.query("select coalesce('n', '') != ''")
# Out:
# Starting query at 2020-04-07T02:55:37.607853
# Query took 0.02
#    ?column?
# 0      True

# %%
print(query)
# Out:
# select
#
#     country_code
#     , dim_page_type.page_type
#     , dim_page_type.page_sub_type
#     , case when page_url like '%/embed/%' then true else false end as is_embed
#     , page_url
#     , device_os
#     , device_category
#     , browser
#     , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'channel', true) as channel
#     , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'product_slug', true) as product_slug
#     , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'product', true) as product
#     , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'product_id', true) as product_id
#     , dim_product.slug as product_from_id
#     , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'provider_slug', true) as provider_slug
#     , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'provider', true) as provider
#     , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'provider_id', true) as provider_id
#     , dim_provider.slug as provider_from_id
#     , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'affiliate_category', true) as affiliate_category
#     , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'affiliate_location', true) as affiliate_location
#     , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'affiliate_page_type', true) as affiliate_page_type
#     , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'affiliate_widget_type', true) as affiliate_widget_type
#     , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'list_position', true) as list_position
#     , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'action', true) as action
#     , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'source', true) as source
#     , dim_activity.activity_attributes
#     from
#
#     -- TODO: cut down the join.s just copy / pasting
#     fact_activities
#     left join dim_page on fact_activities.page_id = dim_page.page_id
#     left join dim_page_type on dim_page_type.page_type_id = dim_page.page_type_id
#     -- left join dim_session on fact_activities.session_id = dim_session.session_id
#     left join dim_activity on fact_activities.activity_id = dim_activity.activity_id
#
#     left join dim_activity_type on fact_activities.activity_type_id = dim_activity_type.activity_type_id
#     left join dim_date on dim_date.date_id = fact_activities.activity_date_id
#     -- left join dim_time on fact_activities.activity_time_id = dim_time.time_id
#     left join dim_country on fact_activities.site_country_id = dim_country.country_id
#
#     left join dim_browser on fact_activities.browser_id = dim_browser.browser_id -- firefox etc
#     left join dim_device on fact_activities.device_id = dim_device.device_id -- device_os, device_category (desktop / mobile...)
#
#     left join dim_channel on dim_channel.channel_key = json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'channel', true)
#     -- only join product and provider if the slug isn't set i.e. assume that it's pre-falcon YMMV (and it's deprecated)
#     left join dim_product on (dim_product.source_product_id = json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'product_id', true)
#         and coalesce(json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'product', true), '') =''
#         and dim_product.channel_id = dim_channel.channel_id
#         and dim_product.country_id = dim_country.country_id)
#     left join dim_provider on (
#         dim_provider.source_provider_id = json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'provider_id', true)
#         and coalesce(json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'provider', true), '') =''
#         and dim_provider.channel_id = dim_channel.channel_id
#             and dim_provider.country_id = dim_country.country_id)
#
#
#
#     where
#         dim_activity_type.activity_name = 'LeadGeneration.ClickConversion'
#
#         and user_filter_type='external_visitor'
#          and dim_date.full_date>='2020-04-04'
#             and dim_date.full_date<='2020-04-06'
#
#
#         -- NB: embeds aren't currently listed as blog pages :(

# %%
type(query)
# Out:
# str

# %%
query = sqlalchemy.text(query)
apply_clicks = dq.query(query)
# Out:
# Starting query at 2020-04-07T02:55:37.642922
# Query took 104.37

# %%
apply_clicks.describe()
# Out:
#        country_code page_type    page_sub_type is_embed  \
# count          4747      4747             4747     4747
# unique            2         4                6        2
# top              sg   listing  channel_listing    False
# freq           3245      2661             1846     4559
#
#                                page_url device_os device_category browser  \
# count                              4747      4747            4747    4747
# unique                              388         7               3      19
# top     www.moneysmart.sg/personal-loan   Android          mobile  Chrome
# freq                                614      2204            3353    1116
#
#              channel product_slug  ... provider_id provider_from_id  \
# count           4747         4747  ...        4747               23
# unique            12            1  ...          46                7
# top     credit-cards               ...           1         citibank
# freq            2574         4747  ...         904                9
#
#        affiliate_category affiliate_location affiliate_page_type  \
# count                4747               4747                4747
# unique                 22                  5                   3
# top
# freq                 4482               4411                4411
#
#        affiliate_widget_type list_position action source  \
# count                   4747          4747   4747   4747
# unique                     4            27      2      5
# top
# freq                    4404          4296   4636   4054
#
#                                       activity_attributes
# count                                                4747
# unique                                               3174
# top     {"channel":"credit-cards","country":"sg","is_p...
# freq                                                   93
#
# [4 rows x 25 columns]

# %%
apply_clicks.head(5)
# Out:
#   country_code page_type     page_sub_type  is_embed  \
# 0           sg   listing   channel_listing     False
# 1           sg   listing   channel_listing     False
# 2           sg   listing   channel_listing     False
# 3           sg   listing   channel_listing     False
# 4           sg   listing  provider_listing     False
#
#                              page_url device_os device_category  \
# 0      www.moneysmart.sg/credit-cards   Android          mobile
# 1      www.moneysmart.sg/credit-cards   Android          mobile
# 2      www.moneysmart.sg/credit-cards   Android          mobile
# 3    www.moneysmart.sg/maid-insurance   Windows         desktop
# 4  www.moneysmart.sg/credit-cards/dbs   Windows         desktop
#
#             browser         channel product_slug  ... provider_id  \
# 0  Samsung Internet    credit-cards               ...           1
# 1  Samsung Internet    credit-cards               ...           1
# 2     Chrome Mobile    credit-cards               ...           9
# 3            Chrome  maid-insurance               ...          21
# 4            Chrome    credit-cards               ...           8
#
#   provider_from_id affiliate_category affiliate_location affiliate_page_type  \
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
#
#   affiliate_widget_type list_position action source  \
# 0
# 1
# 2
# 3
# 4
#
#                                  activity_attributes
# 0  {"channel":"credit-cards","country":"sg","is_p...
# 1  {"channel":"credit-cards","country":"sg","is_p...
# 2  {"channel":"credit-cards","country":"sg","is_p...
# 3  {"channel":"maid-insurance","country":"sg","is...
# 4  {"channel":"credit-cards","country":"sg","is_p...
#
# [5 rows x 25 columns]

# %%
product_provider_summary_cols = [ "page_url", "action", "page_type", "channel"]+ [z for z in apply_clicks.columns if "product" in z or "provider" in z]
afilliate_cols = [z for z in apply_clicks.columns if "affiliate" in z]

# %%
apply_clicks[product_provider_summary_cols ].head()
# Out:
#                              page_url action page_type         channel  \
# 0      www.moneysmart.sg/credit-cards          listing    credit-cards
# 1      www.moneysmart.sg/credit-cards          listing    credit-cards
# 2      www.moneysmart.sg/credit-cards          listing    credit-cards
# 3    www.moneysmart.sg/maid-insurance          listing  maid-insurance
# 4  www.moneysmart.sg/credit-cards/dbs          listing    credit-cards
#
#   product_slug                                            product product_id  \
# 0                                         citi-cashback-plus-card         66
# 1                                         citi-cashback-plus-card         66
# 2               american-express-singapore-airlines-krisflyer-...          7
# 3                                    fwd-maid-insurance-essential          3
# 4                                             dbs-live-fresh-card         61
#
#   product_from_id provider_slug          provider provider_id provider_from_id
# 0            None                        citibank           1             None
# 1            None                        citibank           1             None
# 2            None                american-express           9             None
# 3            None                             fwd          21             None
# 4            None                             dbs           8             None

# %% [markdown]
# ## Issues

# %%
def format_results(df):
    def make_clickable(val):
        # target _blank to open new window
        return '<a target="_blank" href="{}">{}</a>'.format("https://"+ val, val)
    
    return df.style.format({'page_url': make_clickable})

# %% [markdown]
# ### Not having product / provider (slug) set (product_id or provider_id is deprecated)

# %%
df = apply_clicks[(apply_clicks.provider.isna()) | (apply_clicks.provider=="")][product_provider_summary_cols]
print("only first 20 shown")
format_results(df.head(20))
# Out:
# only first 20 shown
# <style  type="text/css" >
# </style><table id="T_3a666262_7881_11ea_a98a_06c0a5c993fa" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >page_url</th>        <th class="col_heading level0 col1" >action</th>        <th class="col_heading level0 col2" >page_type</th>        <th class="col_heading level0 col3" >channel</th>        <th class="col_heading level0 col4" >product_slug</th>        <th class="col_heading level0 col5" >product</th>        <th class="col_heading level0 col6" >product_id</th>        <th class="col_heading level0 col7" >product_from_id</th>        <th class="col_heading level0 col8" >provider_slug</th>        <th class="col_heading level0 col9" >provider</th>        <th class="col_heading level0 col10" >provider_id</th>        <th class="col_heading level0 col11" >provider_from_id</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3a666262_7881_11ea_a98a_06c0a5c993falevel0_row0" class="row_heading level0 row0" >32</th>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow0_col0" class="data row0 col0" ><a target="_blank" href="https://blog.moneysmart.sg/transportation/bus-mrt-fares-public-transport">blog.moneysmart.sg/transportation/bus-mrt-fares-public-transport</a></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow0_col1" class="data row0 col1" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow0_col2" class="data row0 col2" >blog_page</td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow0_col3" class="data row0 col3" >credit-cards</td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow0_col4" class="data row0 col4" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow0_col5" class="data row0 col5" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow0_col6" class="data row0 col6" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow0_col7" class="data row0 col7" >None</td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow0_col8" class="data row0 col8" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow0_col9" class="data row0 col9" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow0_col10" class="data row0 col10" >1</td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow0_col11" class="data row0 col11" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_3a666262_7881_11ea_a98a_06c0a5c993falevel0_row1" class="row_heading level0 row1" >36</th>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow1_col0" class="data row1 col0" ><a target="_blank" href="https://www.moneysmart.hk/zh-hk/health-insurance/vhis-ms">www.moneysmart.hk/zh-hk/health-insurance/vhis-ms</a></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow1_col1" class="data row1 col1" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow1_col2" class="data row1 col2" >Unknown</td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow1_col3" class="data row1 col3" >health-insurance</td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow1_col4" class="data row1 col4" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow1_col5" class="data row1 col5" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow1_col6" class="data row1 col6" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow1_col7" class="data row1 col7" >None</td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow1_col8" class="data row1 col8" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow1_col9" class="data row1 col9" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow1_col10" class="data row1 col10" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow1_col11" class="data row1 col11" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_3a666262_7881_11ea_a98a_06c0a5c993falevel0_row2" class="row_heading level0 row2" >53</th>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow2_col0" class="data row2 col0" ><a target="_blank" href="https://www.moneysmart.sg/investments/online-brokerages-ms">www.moneysmart.sg/investments/online-brokerages-ms</a></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow2_col1" class="data row2 col1" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow2_col2" class="data row2 col2" >Unknown</td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow2_col3" class="data row2 col3" >investments</td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow2_col4" class="data row2 col4" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow2_col5" class="data row2 col5" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow2_col6" class="data row2 col6" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow2_col7" class="data row2 col7" >None</td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow2_col8" class="data row2 col8" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow2_col9" class="data row2 col9" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow2_col10" class="data row2 col10" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow2_col11" class="data row2 col11" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_3a666262_7881_11ea_a98a_06c0a5c993falevel0_row3" class="row_heading level0 row3" >54</th>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow3_col0" class="data row3 col0" ><a target="_blank" href="https://www.moneysmart.sg/investments/online-brokerages-ms">www.moneysmart.sg/investments/online-brokerages-ms</a></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow3_col1" class="data row3 col1" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow3_col2" class="data row3 col2" >Unknown</td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow3_col3" class="data row3 col3" >investments</td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow3_col4" class="data row3 col4" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow3_col5" class="data row3 col5" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow3_col6" class="data row3 col6" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow3_col7" class="data row3 col7" >None</td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow3_col8" class="data row3 col8" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow3_col9" class="data row3 col9" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow3_col10" class="data row3 col10" ></td>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow3_col11" class="data row3 col11" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_3a666262_7881_11ea_a98a_06c0a5c993falevel0_row4" class="row_heading level0 row4" >55</th>
#                         <td id="T_3a666262_7881_11ea_a98a_06c0a5c993farow4_col0" class="data row4 col0" ><a target="_blank" href="https://www.moneysmart.sg/investments/city-index-ms">www.moneysmart.sg/investments/city-index-ms</a></td>
#                         <td id="T_3a666262_7881_11ea_a98a

# %%
df2 = pd.DataFrame(df.groupby(["page_url", "page_type","channel"]).size().reset_index().sort_values(0, ascending=False))
format_results(df2)
# Out:
# <style  type="text/css" >
# </style><table id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993fa" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >page_url</th>        <th class="col_heading level0 col1" >page_type</th>        <th class="col_heading level0 col2" >channel</th>        <th class="col_heading level0 col3" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993falevel0_row0" class="row_heading level0 row0" >91</th>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow0_col0" class="data row0 col0" ><a target="_blank" href="https://www.moneysmart.sg/investments/online-brokerages-ms">www.moneysmart.sg/investments/online-brokerages-ms</a></td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow0_col1" class="data row0 col1" >Unknown</td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow0_col2" class="data row0 col2" >investments</td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow0_col3" class="data row0 col3" >86</td>
#             </tr>
#             <tr>
#                         <th id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993falevel0_row1" class="row_heading level0 row1" >92</th>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow1_col0" class="data row1 col0" ><a target="_blank" href="https://www.moneysmart.sg/investments/saxo-markets-ms">www.moneysmart.sg/investments/saxo-markets-ms</a></td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow1_col1" class="data row1 col1" >Unknown</td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow1_col2" class="data row1 col2" >investments</td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow1_col3" class="data row1 col3" >34</td>
#             </tr>
#             <tr>
#                         <th id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993falevel0_row2" class="row_heading level0 row2" >43</th>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow2_col0" class="data row2 col0" ><a target="_blank" href="https://blog.moneysmart.sg/personal-loans/best-personal-loan-singapore">blog.moneysmart.sg/personal-loans/best-personal-loan-singapore</a></td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow2_col1" class="data row2 col1" >blog_page</td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow2_col2" class="data row2 col2" >personal-loan</td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow2_col3" class="data row2 col3" >22</td>
#             </tr>
#             <tr>
#                         <th id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993falevel0_row3" class="row_heading level0 row3" >73</th>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow3_col0" class="data row3 col0" ><a target="_blank" href="https://www.moneysmart.sg/car-insurance/aig-ms">www.moneysmart.sg/car-insurance/aig-ms</a></td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow3_col1" class="data row3 col1" >Unknown</td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow3_col2" class="data row3 col2" >car-insurance</td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow3_col3" class="data row3 col3" >14</td>
#             </tr>
#             <tr>
#                         <th id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993falevel0_row4" class="row_heading level0 row4" >30</th>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow4_col0" class="data row4 col0" ><a target="_blank" href="https://blog.moneysmart.sg/credit-cards/dbs-credit-cards-singapore-review">blog.moneysmart.sg/credit-cards/dbs-credit-cards-singapore-review</a></td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow4_col1" class="data row4 col1" >blog_page</td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow4_col2" class="data row4 col2" >credit-cards</td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow4_col3" class="data row4 col3" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993falevel0_row5" class="row_heading level0 row5" >44</th>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow5_col0" class="data row5 col0" ><a target="_blank" href="https://blog.moneysmart.sg/savings-accounts/dbs-multiplier-account-review">blog.moneysmart.sg/savings-accounts/dbs-multiplier-account-review</a></td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow5_col1" class="data row5 col1" >blog_page</td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow5_col2" class="data row5 col2" >credit-cards</td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow5_col3" class="data row5 col3" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993falevel0_row6" class="row_heading level0 row6" >48</th>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow6_col0" class="data row6 col0" ><a target="_blank" href="https://blog.moneysmart.sg/shopping/lazada-promo-code-promotion">blog.moneysmart.sg/shopping/lazada-promo-code-promotion</a></td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow6_col1" class="data row6 col1" >blog_page</td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow6_col2" class="data row6 col2" >credit-cards</td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow6_col3" class="data row6 col3" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993falevel0_row7" class="row_heading level0 row7" >67</th>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow7_col0" class="data row7 col0" ><a target="_blank" href="https://www.moneysmart.hk/zh-hk/personal-loan/clear-credit-card-debts-ms">www.moneysmart.hk/zh-hk/personal-loan/clear-credit-card-debts-ms</a></td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow7_col1" class="data row7 col1" >Unknown</td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow7_col2" class="data row7 col2" >personal-loan</td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow7_col3" class="data row7 col3" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993falevel0_row8" class="row_heading level0 row8" >7</th>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow8_col0" class="data row8 col0" ><a target="_blank" href="https://blog.moneysmart.hk/zh-hk/credit-cards/%E9%9B%BB%E5%99%A8%E5%84%AA%E6%83%A0-%E4%BF%A1%E7%94%A8%E5%8D%A1-%E8%B2%B7%E9%9B%BB%E5%99%A8-%E5%84%AA%E6%83%A0">blog.moneysmart.hk/zh-hk/credit-cards/%E9%9B%BB%E5%99%A8%E5%84%AA%E6%83%A0-%E4%BF%A1%E7%94%A8%E5%8D%A1-%E8%B2%B7%E9%9B%BB%E5%99%A8-%E5%84%AA%E6%83%A0</a></td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow8_col1" class="data row8 col1" >blog_page</td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow8_col2" class="data row8 col2" >credit-cards</td>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow8_col3" class="data row8 col3" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993falevel0_row9" class="row_heading level0 row9" >86</th>
#                         <td id="T_7f4cdd20_7881_11ea_a98a_06c0a5c993farow9_col0" class="data row9 col0" ><a target="_blank" href="https://www.moneysmart.sg/embed/9cb432acbab519e7863e0608254b41e7/result">www.moneysmart.sg/embed/9cb432acbab519e7863e0608254b41e7/result</a></td>
#                         <t

# %% [markdown]
# ### Using product_slug or provider_slug not product / provider

# %%
apply_clicks[~(apply_clicks.provider_slug.isna() | (apply_clicks.provider_slug==""))][product_provider_summary_cols]
# Out:
# Empty DataFrame
# Columns: [page_url, action, page_type, channel, product_slug, product, product_id, product_from_id, provider_slug, provider, provider_id, provider_from_id]
# Index: []

# %%
apply_clicks[~(apply_clicks["product_slug"].isna() | (apply_clicks["product_slug"]==""))][product_provider_summary_cols]
# Out:
# Empty DataFrame
# Columns: [page_url, action, page_type, channel, product_slug, product, product_id, product_from_id, provider_slug, provider, provider_id, provider_from_id]
# Index: []

# %% [markdown]
# ### Not having any product or provider info

# %%
# No product info
df = apply_clicks[(apply_clicks["product"].isna() | (apply_clicks["product"]=="")) & (apply_clicks.product_id.isna() | ((apply_clicks["product_id"]=="")))][product_provider_summary_cols]
df2 = pd.DataFrame(df.groupby(["page_url", "page_type", "channel"]).size()).reset_index().sort_values(0, ascending=False).rename(columns={0:"click count"})
format_results(df2)
# Out:
# <style  type="text/css" >
# </style><table id="T_80964afa_787b_11ea_a98a_06c0a5c993fa" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >page_url</th>        <th class="col_heading level0 col1" >page_type</th>        <th class="col_heading level0 col2" >channel</th>        <th class="col_heading level0 col3" >click count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_80964afa_787b_11ea_a98a_06c0a5c993falevel0_row0" class="row_heading level0 row0" >77</th>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow0_col0" class="data row0 col0" ><a target="_blank" href="https://www.moneysmart.sg/investments/online-brokerages-ms">www.moneysmart.sg/investments/online-brokerages-ms</a></td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow0_col1" class="data row0 col1" >Unknown</td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow0_col2" class="data row0 col2" >investments</td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow0_col3" class="data row0 col3" >86</td>
#             </tr>
#             <tr>
#                         <th id="T_80964afa_787b_11ea_a98a_06c0a5c993falevel0_row1" class="row_heading level0 row1" >78</th>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow1_col0" class="data row1 col0" ><a target="_blank" href="https://www.moneysmart.sg/investments/saxo-markets-ms">www.moneysmart.sg/investments/saxo-markets-ms</a></td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow1_col1" class="data row1 col1" >Unknown</td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow1_col2" class="data row1 col2" >investments</td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow1_col3" class="data row1 col3" >34</td>
#             </tr>
#             <tr>
#                         <th id="T_80964afa_787b_11ea_a98a_06c0a5c993falevel0_row2" class="row_heading level0 row2" >43</th>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow2_col0" class="data row2 col0" ><a target="_blank" href="https://blog.moneysmart.sg/personal-loans/best-personal-loan-singapore">blog.moneysmart.sg/personal-loans/best-personal-loan-singapore</a></td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow2_col1" class="data row2 col1" >blog_page</td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow2_col2" class="data row2 col2" >personal-loan</td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow2_col3" class="data row2 col3" >22</td>
#             </tr>
#             <tr>
#                         <th id="T_80964afa_787b_11ea_a98a_06c0a5c993falevel0_row3" class="row_heading level0 row3" >67</th>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow3_col0" class="data row3 col0" ><a target="_blank" href="https://www.moneysmart.sg/car-insurance/aig-ms">www.moneysmart.sg/car-insurance/aig-ms</a></td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow3_col1" class="data row3 col1" >Unknown</td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow3_col2" class="data row3 col2" >car-insurance</td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow3_col3" class="data row3 col3" >14</td>
#             </tr>
#             <tr>
#                         <th id="T_80964afa_787b_11ea_a98a_06c0a5c993falevel0_row4" class="row_heading level0 row4" >30</th>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow4_col0" class="data row4 col0" ><a target="_blank" href="https://blog.moneysmart.sg/credit-cards/dbs-credit-cards-singapore-review">blog.moneysmart.sg/credit-cards/dbs-credit-cards-singapore-review</a></td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow4_col1" class="data row4 col1" >blog_page</td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow4_col2" class="data row4 col2" >credit-cards</td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow4_col3" class="data row4 col3" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_80964afa_787b_11ea_a98a_06c0a5c993falevel0_row5" class="row_heading level0 row5" >48</th>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow5_col0" class="data row5 col0" ><a target="_blank" href="https://blog.moneysmart.sg/shopping/lazada-promo-code-promotion">blog.moneysmart.sg/shopping/lazada-promo-code-promotion</a></td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow5_col1" class="data row5 col1" >blog_page</td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow5_col2" class="data row5 col2" >credit-cards</td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow5_col3" class="data row5 col3" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_80964afa_787b_11ea_a98a_06c0a5c993falevel0_row6" class="row_heading level0 row6" >44</th>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow6_col0" class="data row6 col0" ><a target="_blank" href="https://blog.moneysmart.sg/savings-accounts/dbs-multiplier-account-review">blog.moneysmart.sg/savings-accounts/dbs-multiplier-account-review</a></td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow6_col1" class="data row6 col1" >blog_page</td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow6_col2" class="data row6 col2" >credit-cards</td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow6_col3" class="data row6 col3" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_80964afa_787b_11ea_a98a_06c0a5c993falevel0_row7" class="row_heading level0 row7" >62</th>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow7_col0" class="data row7 col0" ><a target="_blank" href="https://www.moneysmart.hk/zh-hk/personal-loan/clear-credit-card-debts-ms">www.moneysmart.hk/zh-hk/personal-loan/clear-credit-card-debts-ms</a></td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow7_col1" class="data row7 col1" >Unknown</td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow7_col2" class="data row7 col2" >personal-loan</td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow7_col3" class="data row7 col3" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_80964afa_787b_11ea_a98a_06c0a5c993falevel0_row8" class="row_heading level0 row8" >7</th>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow8_col0" class="data row8 col0" ><a target="_blank" href="https://blog.moneysmart.hk/zh-hk/credit-cards/%E9%9B%BB%E5%99%A8%E5%84%AA%E6%83%A0-%E4%BF%A1%E7%94%A8%E5%8D%A1-%E8%B2%B7%E9%9B%BB%E5%99%A8-%E5%84%AA%E6%83%A0">blog.moneysmart.hk/zh-hk/credit-cards/%E9%9B%BB%E5%99%A8%E5%84%AA%E6%83%A0-%E4%BF%A1%E7%94%A8%E5%8D%A1-%E8%B2%B7%E9%9B%BB%E5%99%A8-%E5%84%AA%E6%83%A0</a></td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow8_col1" class="data row8 col1" >blog_page</td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow8_col2" class="data row8 col2" >credit-cards</td>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow8_col3" class="data row8 col3" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_80964afa_787b_11ea_a98a_06c0a5c993falevel0_row9" class="row_heading level0 row9" >56</th>
#                         <td id="T_80964afa_787b_11ea_a98a_06c0a5c993farow9_col0" class="data row9 col0" ><a target="_blank" href="https://www.moneysmart.hk/zh-hk/health-insurance/vhis-ms">www.moneysmart.hk/zh-hk/health-insurance/vhis-ms</a></td>
#                         <td id="T_80964afa_787

# %%
# No provider info
apply_clicks[(apply_clicks.provider.isna() | (apply_clicks.provider==""))][product_provider_summary_cols]
# Out:
#                                                page_url      action  \
# 32    blog.moneysmart.sg/transportation/bus-mrt-fare...
# 36     www.moneysmart.hk/zh-hk/health-insurance/vhis-ms
# 53    www.moneysmart.sg/investments/online-brokerage...
# 54    www.moneysmart.sg/investments/online-brokerage...
# 55          www.moneysmart.sg/investments/city-index-ms
# 56    blog.moneysmart.sg/credit-cards/dbs-credit-car...
# 69    blog.moneysmart.sg/personal-loans/best-persona...
# 107   www.moneysmart.hk/zh-hk/credit-cards/annual-fe...
# 119   blog.moneysmart.sg/credit-cards/dbs-live-fresh...
# 148   blog.moneysmart.sg/credit-cards/credit-cards-s...
# 161   blog.moneysmart.sg/credit-cards/best-rewards-c...
# 165   www.moneysmart.hk/zh-hk/personal-loan/no-credi...
# 168   www.moneysmart.sg/embed/9cb432acbab519e7863e06...
# 169       www.moneysmart.sg/investments/saxo-markets-ms
# 170   www.moneysmart.sg/investments/online-brokerage...
# 181   blog.moneysmart.sg/budgeting/cheapest-sim-only...
# 202   blog.moneysmart.hk/zh-hk/credit-cards/%E9%9B%B...
# 209         www.moneysmart.sg/investments/ig-markets-ms
# 219   www.moneysmart.sg/investments/online-brokerage...
# 252              www.moneysmart.sg/car-insurance/aig-ms
# 262   www.moneysmart.sg/travel-insurance/travel-insu...
# 263       www.moneysmart.sg/investments/saxo-markets-ms
# 273   www.moneysmart.hk/zh-hk/personal-loan/best-hsb...
# 285   www.moneysmart.hk/zh-hk/personal-loan/best-dbs...
# 297   www.moneysmart.sg/embed/5051cca749bae55521c343...
# 303   blog.moneysmart.sg/credit-cards/citibank-smrt-...
# 320   www.moneysmart.sg/investments/online-brokerage...
# 345            www.moneysmart.sg/car-insurance/aviva-ms
# 358       www.moneysmart.sg/investments/saxo-markets-ms
# 359   www.moneysmart.sg/investments/online-brokerage...
# ...                                                 ...         ...
# 4317  www.moneysmart.sg/investments/online-brokerage...
# 4328  www.moneysmart.hk/zh-hk/credit-cards/annual-fe...
# 4332  blog.moneysmart.sg/savings-accounts/dbs-multip...
# 4333        www.moneysmart.sg/investments/city-index-ms
# 4335  www.moneysmart.hk/zh-hk/personal-loan/best-ban...
# 4378  blog.moneysmart.sg/savings-accounts/dbs-multip...
# 4422  www.moneysmart.sg/investments/online-brokerage...
# 4423  blog.moneysmart.sg/credit-cards/ocbc-365-credi...
# 4465  www.moneysmart.hk/zh-hk/personal-loan/clear-cr...
# 4483        www.moneysmart.sg/investments/city-index-ms
# 4488  blog.moneysmart.hk/zh-hk/credit-cards/%E6%84%9...
# 4502  www.moneysmart.sg/investments/online-brokerage...
# 4515      www.moneysmart.sg/investments/saxo-markets-ms
# 4567  blog.moneysmart.sg/credit-cards/dbs-altitude-c...
# 4571  www.moneysmart.hk/zh-hk/investments/retirement...
# 4577  blog.moneysmart.hk/zh-hk/budgeting/%E5%84%AA%E...
# 4596  www.moneysmart.sg/embed/9cb432acbab519e7863e06...
# 4602  www.moneysmart.hk/zh-hk/credit-cards/annual-fe...
# 4603  www.moneysmart.sg/car-insurance/fwd/driver-det...  conversion
# 4609  blog.moneysmart.sg/shopping/lazada-promo-code-...
# 4625  www.moneysmart.sg/investments/online-brokerage...
# 4641  blog.moneysmart.hk/zh-hk/budgeting/iphone-11-%...
# 4661  www.moneysmart.hk/zh-hk/personal-loan/no-credi...
# 4673  www.moneysmart.sg/investments/online-brokerage...
# 4674  blog.moneysmart.sg/credit-cards/cimb-credit-ca...
# 4688            www.moneysmart.sg/car-insurance/msig-ms
# 4723             www.moneysmart.sg/car-insurance/aig-ms
# 4730  blog.moneysmart.sg/credit-cards/best-student-c...
# 4735  blog.moneysmart.hk/zh-hk/credit-cards/%e9%9b%b...
# 4744  www.moneysmart.hk/zh-hk/personal-loan/no-credi...
#
#       page_type           channel product_slug product product_id  \
# 32    blog_page      credit-cards
# 36      Unknown  health-insurance
# 53      Unknown       investments
# 54      Unknown       investments
# 55      Unknown       investments
# 56    blog_page      credit-cards
# 69    blog_page     personal-loan
# 107     Unknown      credit-cards
# 119   blog_page      credit-cards
# 148   blog_page      credit-cards
# 161   blog_page      credit-cards
# 165     Unknown     personal-loan
# 168     Unknown       refinancing                            2319
# 169     Unknown       investments
# 170     Unknown       investments
# 181   blog_page      credit-cards
# 202   blog_page      credit-cards
# 209     Unknown       investments
# 219     Unknown       investments
# 252     Unknown     car-insurance
# 262     Unknown  travel-insurance
# 263     Unknown       investments
# 273     Unknown     personal-loan
# 285     Unknown     personal-loan
# 297     Unknown       refinancing                            2392
# 303   blog_page      credit-cards
# 320     Unknown       investments
# 345     Unknown     car-insurance
# 358     Unknown       investments
# 359     Unknown       investments
# ...         ...               ...          ...     ...        ...
# 4317    Unknown       investments
# 4328    Unknown      credit-cards
# 4332  blog_page      credit-cards
# 4333    Unknown       investments
# 4335    Unknown     personal-loan
# 4378  blog_page      credit-cards
# 4422    Unknown       investments
# 4423  blog_page      credit-cards
# 4465    Unknown     personal-loan
# 4483    Unknown       investments
# 4488  blog_page      credit-cards
# 4502    Unknown       investments
# 4515    Unknown       investments
# 4567  blog_page      credit-cards
# 4571    Unknown       investments
# 4577  blog_page      credit-cards
# 4596    Unknown       refinancing                            2517
# 4602    Unknown      credit-cards
# 4603    Unknown     car-insurance                             108
# 4609  blog_page      credit-cards
# 4625    Unknown       investments
# 4641  blog_page      credit-cards
# 4661    Unknown     personal-loan
# 4673    Unknown       investments
# 4674  blog_page      credit-cards
# 4688    Unknown     car-insurance
# 4723    Unknown     car-insurance
# 4730  blog_page      credit-cards
# 4735  blog_page      credit-cards
# 4744    Unknown     personal-loan
#
#      product_from_id provider_slug provider provider_id provider_from_id
# 32              None                                  1             None
# 36              None                                                None
# 53              None                                                None
# 54              None                                                None
# 55              None                                                None
# 56              None                                  4             None
# 69              None                                  7              uob
# 107             None                                                None
# 119             None                                  8             None
# 148             None                                  8             None
# 161             None                                  1             None
# 165             None                                                None
# 168             None                                                None
# 169             None                                                None
# 170             None                                                None
# 181             None                                 12             None
# 202             None                                 19             None
# 209             None                                                None
# 219             None                                                None
# 252             None                                                None
# 262             None                                                None
# 263             None                                                None
# 273             None                                                None
# 285             None                                                None
# 297             None                                                None
# 303             None                                  1             None
# 320             None                                                None
# 345             None                                                None
# 358             None                                                None
# 359             None                                                None
# ...              ...           ...      ...         ...              ...
# 4317            None                                                None
# 4328            None                                                None
# 4332            None                                  8             None
# 4333            None                                                None
# 4335            None                                                None
# 4378            None                                  8             None
# 4422            None                                                None
# 4423            None                                  7             None
# 4465            None                                                None
# 4483            None                                                None
# 4488            None                                 18             None
# 4502            None                                                None
# 4515            None                                                None
# 4567            None                                  8             None
# 4571            None                                                None
# 4577            None                                 11             None
# 4596            None                                                None
# 4602            None                                                None
# 4603            None                                 88             None
# 4609            None                                  8             None
# 4625            None                                                None
# 4641            None                                 13             None
# 4661            None                                                None
# 4673            None                                                None
# 4674            None                                  6             None
# 4688            None                                                None
# 4723            None                                                None
# 4730            None                                  8             None
# 4735            None                                 14             None
# 4744            None                                                None
#
# [445 rows x 12 columns]

# %%
# No product or provider info, grouped by number of clicks on the page
missing_providers = apply_clicks[((apply_clicks.provider=="" ) | (apply_clicks.provider.isna())) & ((apply_clicks.provider_id=="" ) | (apply_clicks.provider_id.isna())) ][["page_url", "provider", "provider_id"]]
missing_providers_grouped = missing_providers.groupby(["page_url"]).size().reset_index() #.rename(columns={0:"click count"})
#missing_providers_grouped.sort_values("provider_id", ascending=False)
format_results(pd.DataFrame(missing_providers_grouped.sort_values(0, ascending=False)))
# Out:
# <style  type="text/css" >
# </style><table id="T_80a35d08_787b_11ea_a98a_06c0a5c993fa" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >page_url</th>        <th class="col_heading level0 col1" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_80a35d08_787b_11ea_a98a_06c0a5c993falevel0_row0" class="row_heading level0 row0" >29</th>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow0_col0" class="data row0 col0" ><a target="_blank" href="https://www.moneysmart.sg/investments/online-brokerages-ms">www.moneysmart.sg/investments/online-brokerages-ms</a></td>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow0_col1" class="data row0 col1" >86</td>
#             </tr>
#             <tr>
#                         <th id="T_80a35d08_787b_11ea_a98a_06c0a5c993falevel0_row1" class="row_heading level0 row1" >30</th>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow1_col0" class="data row1 col0" ><a target="_blank" href="https://www.moneysmart.sg/investments/saxo-markets-ms">www.moneysmart.sg/investments/saxo-markets-ms</a></td>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow1_col1" class="data row1 col1" >34</td>
#             </tr>
#             <tr>
#                         <th id="T_80a35d08_787b_11ea_a98a_06c0a5c993falevel0_row2" class="row_heading level0 row2" >15</th>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow2_col0" class="data row2 col0" ><a target="_blank" href="https://www.moneysmart.sg/car-insurance/aig-ms">www.moneysmart.sg/car-insurance/aig-ms</a></td>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow2_col1" class="data row2 col1" >14</td>
#             </tr>
#             <tr>
#                         <th id="T_80a35d08_787b_11ea_a98a_06c0a5c993falevel0_row3" class="row_heading level0 row3" >25</th>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow3_col0" class="data row3 col0" ><a target="_blank" href="https://www.moneysmart.sg/embed/9cb432acbab519e7863e0608254b41e7/result">www.moneysmart.sg/embed/9cb432acbab519e7863e0608254b41e7/result</a></td>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow3_col1" class="data row3 col1" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_80a35d08_787b_11ea_a98a_06c0a5c993falevel0_row4" class="row_heading level0 row4" >24</th>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow4_col0" class="data row4 col0" ><a target="_blank" href="https://www.moneysmart.sg/embed/5051cca749bae55521c34317d0799cae/result">www.moneysmart.sg/embed/5051cca749bae55521c34317d0799cae/result</a></td>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow4_col1" class="data row4 col1" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_80a35d08_787b_11ea_a98a_06c0a5c993falevel0_row5" class="row_heading level0 row5" >10</th>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow5_col0" class="data row5 col0" ><a target="_blank" href="https://www.moneysmart.hk/zh-hk/personal-loan/clear-credit-card-debts-ms">www.moneysmart.hk/zh-hk/personal-loan/clear-credit-card-debts-ms</a></td>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow5_col1" class="data row5 col1" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_80a35d08_787b_11ea_a98a_06c0a5c993falevel0_row6" class="row_heading level0 row6" >4</th>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow6_col0" class="data row6 col0" ><a target="_blank" href="https://www.moneysmart.hk/zh-hk/health-insurance/vhis-ms">www.moneysmart.hk/zh-hk/health-insurance/vhis-ms</a></td>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow6_col1" class="data row6 col1" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_80a35d08_787b_11ea_a98a_06c0a5c993falevel0_row7" class="row_heading level0 row7" >22</th>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow7_col0" class="data row7 col0" ><a target="_blank" href="https://www.moneysmart.sg/car-insurance/ntuc-ms">www.moneysmart.sg/car-insurance/ntuc-ms</a></td>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow7_col1" class="data row7 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_80a35d08_787b_11ea_a98a_06c0a5c993falevel0_row8" class="row_heading level0 row8" >5</th>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow8_col0" class="data row8 col0" ><a target="_blank" href="https://www.moneysmart.hk/zh-hk/investments/retirement-products-deduct-taxes-ms">www.moneysmart.hk/zh-hk/investments/retirement-products-deduct-taxes-ms</a></td>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow8_col1" class="data row8 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_80a35d08_787b_11ea_a98a_06c0a5c993falevel0_row9" class="row_heading level0 row9" >13</th>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow9_col0" class="data row9 col0" ><a target="_blank" href="https://www.moneysmart.hk/zh-hk/personal-loan/no-credit-check-loans-ms">www.moneysmart.hk/zh-hk/personal-loan/no-credit-check-loans-ms</a></td>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow9_col1" class="data row9 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_80a35d08_787b_11ea_a98a_06c0a5c993falevel0_row10" class="row_heading level0 row10" >0</th>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow10_col0" class="data row10 col0" ><a target="_blank" href="https://www.moneysmart.hk/zh-hk/credit-cards/annual-fee-waiver-ms">www.moneysmart.hk/zh-hk/credit-cards/annual-fee-waiver-ms</a></td>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow10_col1" class="data row10 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_80a35d08_787b_11ea_a98a_06c0a5c993falevel0_row11" class="row_heading level0 row11" >27</th>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow11_col0" class="data row11 col0" ><a target="_blank" href="https://www.moneysmart.sg/investments/city-index-ms">www.moneysmart.sg/investments/city-index-ms</a></td>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow11_col1" class="data row11 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_80a35d08_787b_11ea_a98a_06c0a5c993falevel0_row12" class="row_heading level0 row12" >8</th>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow12_col0" class="data row12 col0" ><a target="_blank" href="https://www.moneysmart.hk/zh-hk/personal-loan/best-hsbc-personal-loan-ms">www.moneysmart.hk/zh-hk/personal-loan/best-hsbc-personal-loan-ms</a></td>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow12_col1" class="data row12 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_80a35d08_787b_11ea_a98a_06c0a5c993falevel0_row13" class="row_heading level0 row13" >21</th>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow13_col0" class="data row13 col0" ><a target="_blank" href="https://www.moneysmart.sg/car-insurance/msig-ms">www.moneysmart.sg/car-insurance/msig-ms</a></td>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow13_col1" class="data row13 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_80a35d08_787b_11ea_a98a_06c0a5c993falevel0_row14" class="row_heading level0 row14" >20</th>
#                         <td id="T_80a35d08_787b_11ea_a98a_06c0a5c993farow14_col0" class="data row14 col0" ><a target="_blank" href="https://www.moneysmart.sg/car-insur

# %% [markdown]
# ### Embed without any info about the page that it's on

# %%
print("all of them!")
# Out:
# all of them!

# %% [markdown]
# ### Blog page without affiliate stuff set
# Blog should have full details of e.g. where on the page it is coming from

# %%
apply_clicks.page_type.unique()
# Out:
# array(['listing', 'Unknown', 'blog_page', 'details'], dtype=object)

# %%
df = apply_clicks[ apply_clicks.page_type.isin(["blog_page"]) & ((apply_clicks.affiliate_category=="") | (apply_clicks.affiliate_location=="") | (apply_clicks.affiliate_page_type=="") |  (apply_clicks.affiliate_widget_type=="")\
             | (apply_clicks.affiliate_category.isna()) | (apply_clicks.affiliate_location.isna()) | (apply_clicks.affiliate_page_type.isna()) |  (apply_clicks.affiliate_widget_type.isna()))][product_provider_summary_cols + afiliate_cols]

format_results(df)
# Out:
# <style  type="text/css" >
# </style><table id="T_80a8f9a2_787b_11ea_a98a_06c0a5c993fa" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >page_url</th>        <th class="col_heading level0 col1" >action</th>        <th class="col_heading level0 col2" >page_type</th>        <th class="col_heading level0 col3" >channel</th>        <th class="col_heading level0 col4" >product_slug</th>        <th class="col_heading level0 col5" >product</th>        <th class="col_heading level0 col6" >product_id</th>        <th class="col_heading level0 col7" >product_from_id</th>        <th class="col_heading level0 col8" >provider_slug</th>        <th class="col_heading level0 col9" >provider</th>        <th class="col_heading level0 col10" >provider_id</th>        <th class="col_heading level0 col11" >provider_from_id</th>        <th class="col_heading level0 col12" >affiliate_category</th>        <th class="col_heading level0 col13" >affiliate_location</th>        <th class="col_heading level0 col14" >affiliate_page_type</th>        <th class="col_heading level0 col15" >affiliate_widget_type</th>    </tr></thead><tbody>
#         </tbody></table>

# %%
"""
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'affiliate_category', true) as affiliate_category
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'affiliate_location', true) as affiliate_location
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'affiliate_page_type', true) as affiliate_page_type
    , json_extract_path_text(trim('"' from dim_activity.activity_attributes), 'affiliate_widget_type', true) as affiliate_widget_type

"""
# Out:
# '\n    , json_extract_path_text(trim(\'"\' from dim_activity.activity_attributes), \'affiliate_category\', true) as affiliate_category\n    , json_extract_path_text(trim(\'"\' from dim_activity.activity_attributes), \'affiliate_location\', true) as affiliate_location\n    , json_extract_path_text(trim(\'"\' from dim_activity.activity_attributes), \'affiliate_page_type\', true) as affiliate_page_type\n    , json_extract_path_text(trim(\'"\' from dim_activity.activity_attributes), \'affiliate_widget_type\', true) as affiliate_widget_type\n\n'

# %% [markdown]
# ### Fails to join on provider_id or product_id
#
# Note that you might expect some pre-falcon stuff in HK not to join as we didn't have the application database loaded.

# %%
# product_id is set, but product_from_id is null
df = apply_clicks[((apply_clicks["product"]=="") | apply_clicks["product"].isna()) & apply_clicks.product_id.str.isnumeric() & apply_clicks.product_from_id.isna()][product_provider_summary_cols]
format_results(df)
# Out:
# <style  type="text/css" >
# </style><table id="T_80ac42f6_787b_11ea_a98a_06c0a5c993fa" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >page_url</th>        <th class="col_heading level0 col1" >action</th>        <th class="col_heading level0 col2" >page_type</th>        <th class="col_heading level0 col3" >channel</th>        <th class="col_heading level0 col4" >product_slug</th>        <th class="col_heading level0 col5" >product</th>        <th class="col_heading level0 col6" >product_id</th>        <th class="col_heading level0 col7" >product_from_id</th>        <th class="col_heading level0 col8" >provider_slug</th>        <th class="col_heading level0 col9" >provider</th>        <th class="col_heading level0 col10" >provider_id</th>        <th class="col_heading level0 col11" >provider_from_id</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_80ac42f6_787b_11ea_a98a_06c0a5c993falevel0_row0" class="row_heading level0 row0" >105</th>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow0_col0" class="data row0 col0" ><a target="_blank" href="https://www.moneysmart.sg/car-insurance/wizard/results">www.moneysmart.sg/car-insurance/wizard/results</a></td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow0_col1" class="data row0 col1" >conversion</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow0_col2" class="data row0 col2" >Unknown</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow0_col3" class="data row0 col3" >car-insurance</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow0_col4" class="data row0 col4" ></td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow0_col5" class="data row0 col5" ></td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow0_col6" class="data row0 col6" >106</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow0_col7" class="data row0 col7" >None</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow0_col8" class="data row0 col8" ></td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow0_col9" class="data row0 col9" >FWD</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow0_col10" class="data row0 col10" >88</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow0_col11" class="data row0 col11" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_80ac42f6_787b_11ea_a98a_06c0a5c993falevel0_row1" class="row_heading level0 row1" >132</th>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow1_col0" class="data row1 col0" ><a target="_blank" href="https://www.moneysmart.sg/car-insurance/wizard/results">www.moneysmart.sg/car-insurance/wizard/results</a></td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow1_col1" class="data row1 col1" >conversion</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow1_col2" class="data row1 col2" >Unknown</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow1_col3" class="data row1 col3" >car-insurance</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow1_col4" class="data row1 col4" ></td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow1_col5" class="data row1 col5" ></td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow1_col6" class="data row1 col6" >120</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow1_col7" class="data row1 col7" >None</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow1_col8" class="data row1 col8" ></td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow1_col9" class="data row1 col9" >Tokio Marine</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow1_col10" class="data row1 col10" >89</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow1_col11" class="data row1 col11" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_80ac42f6_787b_11ea_a98a_06c0a5c993falevel0_row2" class="row_heading level0 row2" >167</th>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow2_col0" class="data row2 col0" ><a target="_blank" href="https://www.moneysmart.sg/car-insurance/wizard/results">www.moneysmart.sg/car-insurance/wizard/results</a></td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow2_col1" class="data row2 col1" >conversion</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow2_col2" class="data row2 col2" >Unknown</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow2_col3" class="data row2 col3" >car-insurance</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow2_col4" class="data row2 col4" ></td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow2_col5" class="data row2 col5" ></td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow2_col6" class="data row2 col6" >107</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow2_col7" class="data row2 col7" >None</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow2_col8" class="data row2 col8" ></td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow2_col9" class="data row2 col9" >FWD</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow2_col10" class="data row2 col10" >88</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow2_col11" class="data row2 col11" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_80ac42f6_787b_11ea_a98a_06c0a5c993falevel0_row3" class="row_heading level0 row3" >168</th>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow3_col0" class="data row3 col0" ><a target="_blank" href="https://www.moneysmart.sg/embed/9cb432acbab519e7863e0608254b41e7/result">www.moneysmart.sg/embed/9cb432acbab519e7863e0608254b41e7/result</a></td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow3_col1" class="data row3 col1" ></td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow3_col2" class="data row3 col2" >Unknown</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow3_col3" class="data row3 col3" >refinancing</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow3_col4" class="data row3 col4" ></td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow3_col5" class="data row3 col5" ></td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow3_col6" class="data row3 col6" >2319</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow3_col7" class="data row3 col7" >None</td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow3_col8" class="data row3 col8" ></td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow3_col9" class="data row3 col9" ></td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow3_col10" class="data row3 col10" ></td>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow3_col11" class="data row3 col11" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_80ac42f6_787b_11ea_a98a_06c0a5c993falevel0_row4" class="row_heading level0 row4" >231</th>
#                         <td id="T_80ac42f6_787b_11ea_a98a_06c0a5c993farow4_col0" class="data row4 col0" ><a target="_blank" href="https://www.moneysmart.sg/car-insurance/wizard/results">www.moneysmart.sg/car-insurance/wizard/results</a></td>

# %%
# provider can't be interpreted from provider_id
df = apply_clicks[((apply_clicks["provider"]=="") | apply_clicks["provider"].isna()) & apply_clicks.provider_id.str.isnumeric() & apply_clicks.provider_from_id.isna()][product_provider_summary_cols]
print(len(df))
format_results(df)
# Out:
# 153
# <style  type="text/css" >
# </style><table id="T_80ba64d0_787b_11ea_a98a_06c0a5c993fa" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >page_url</th>        <th class="col_heading level0 col1" >action</th>        <th class="col_heading level0 col2" >page_type</th>        <th class="col_heading level0 col3" >channel</th>        <th class="col_heading level0 col4" >product_slug</th>        <th class="col_heading level0 col5" >product</th>        <th class="col_heading level0 col6" >product_id</th>        <th class="col_heading level0 col7" >product_from_id</th>        <th class="col_heading level0 col8" >provider_slug</th>        <th class="col_heading level0 col9" >provider</th>        <th class="col_heading level0 col10" >provider_id</th>        <th class="col_heading level0 col11" >provider_from_id</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_80ba64d0_787b_11ea_a98a_06c0a5c993falevel0_row0" class="row_heading level0 row0" >32</th>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow0_col0" class="data row0 col0" ><a target="_blank" href="https://blog.moneysmart.sg/transportation/bus-mrt-fares-public-transport">blog.moneysmart.sg/transportation/bus-mrt-fares-public-transport</a></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow0_col1" class="data row0 col1" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow0_col2" class="data row0 col2" >blog_page</td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow0_col3" class="data row0 col3" >credit-cards</td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow0_col4" class="data row0 col4" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow0_col5" class="data row0 col5" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow0_col6" class="data row0 col6" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow0_col7" class="data row0 col7" >None</td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow0_col8" class="data row0 col8" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow0_col9" class="data row0 col9" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow0_col10" class="data row0 col10" >1</td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow0_col11" class="data row0 col11" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_80ba64d0_787b_11ea_a98a_06c0a5c993falevel0_row1" class="row_heading level0 row1" >56</th>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow1_col0" class="data row1 col0" ><a target="_blank" href="https://blog.moneysmart.sg/credit-cards/dbs-credit-cards-singapore-review">blog.moneysmart.sg/credit-cards/dbs-credit-cards-singapore-review</a></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow1_col1" class="data row1 col1" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow1_col2" class="data row1 col2" >blog_page</td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow1_col3" class="data row1 col3" >credit-cards</td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow1_col4" class="data row1 col4" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow1_col5" class="data row1 col5" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow1_col6" class="data row1 col6" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow1_col7" class="data row1 col7" >None</td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow1_col8" class="data row1 col8" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow1_col9" class="data row1 col9" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow1_col10" class="data row1 col10" >4</td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow1_col11" class="data row1 col11" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_80ba64d0_787b_11ea_a98a_06c0a5c993falevel0_row2" class="row_heading level0 row2" >119</th>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow2_col0" class="data row2 col0" ><a target="_blank" href="https://blog.moneysmart.sg/credit-cards/dbs-live-fresh-card-review">blog.moneysmart.sg/credit-cards/dbs-live-fresh-card-review</a></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow2_col1" class="data row2 col1" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow2_col2" class="data row2 col2" >blog_page</td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow2_col3" class="data row2 col3" >credit-cards</td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow2_col4" class="data row2 col4" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow2_col5" class="data row2 col5" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow2_col6" class="data row2 col6" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow2_col7" class="data row2 col7" >None</td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow2_col8" class="data row2 col8" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow2_col9" class="data row2 col9" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow2_col10" class="data row2 col10" >8</td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow2_col11" class="data row2 col11" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_80ba64d0_787b_11ea_a98a_06c0a5c993falevel0_row3" class="row_heading level0 row3" >148</th>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow3_col0" class="data row3 col0" ><a target="_blank" href="https://blog.moneysmart.sg/credit-cards/credit-cards-singapore-free-airport-lounge-access">blog.moneysmart.sg/credit-cards/credit-cards-singapore-free-airport-lounge-access</a></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow3_col1" class="data row3 col1" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow3_col2" class="data row3 col2" >blog_page</td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow3_col3" class="data row3 col3" >credit-cards</td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow3_col4" class="data row3 col4" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow3_col5" class="data row3 col5" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow3_col6" class="data row3 col6" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow3_col7" class="data row3 col7" >None</td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow3_col8" class="data row3 col8" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow3_col9" class="data row3 col9" ></td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow3_col10" class="data row3 col10" >8</td>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow3_col11" class="data row3 col11" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_80ba64d0_787b_11ea_a98a_06c0a5c993falevel0_row4" class="row_heading level0 row4" >161</th>
#                         <td id="T_80ba64d0_787b_11ea_a98a_06c0a5c993farow4_col0" class="data row4 col0" ><a target="_blank" href="https://blog.moneysmart.sg/credit-cards/b

# %%
providers_channels[providers_channels.source_provider_id == 1]
# Out:
#      provider_id provider_name             sys_inserted_x  \
# 127          838          HSBC 2019-02-19 19:32:36.488054
# 140         5944           DBS 2019-06-13 19:34:26.014648
# 380         1901          HSBC 2019-03-18 07:48:04.367002
# 390         5970           DBS 2019-06-13 19:34:26.014648
#
#                  sys_updated_x  source_provider_id  slug  status  channel_id  \
# 127 2019-02-19 19:32:36.488054                 1.0  hsbc       1          16
# 140 2019-06-13 19:34:26.014648                 1.0   dbs       1          17
# 380 2019-03-18 07:48:04.367002                 1.0  hsbc       1          24
# 390 2019-06-13 19:34:26.014648                 1.0   dbs       1          10
#
#      country_id  language_id              channel_key  \
# 127           1            1            personal-loan
# 140           1            1              refinancing
# 380           1            1  debt-consolidation-plan
# 390           1            1                home-loan
#
#                 channel_name             sys_inserted_y  \
# 127            Personal Loan 2018-09-11 10:11:04.481062
# 140    Home Loan Refinancing 2018-09-11 10:11:04.481062
# 380  Debt Consolidation Plan 2019-03-18 07:40:50.126887
# 390                Home Loan 2018-09-11 10:11:04.481062
#
#                  sys_updated_y
# 127 2018-09-11 10:11:04.481062
# 140 2018-09-11 10:11:04.481062
# 380 2019-03-18 07:40:50.126887
# 390 2018-09-11 10:11:04.481062

# %%
providers_channels[~providers_channels.source_provider_id.isna()][providers_channels.source_provider_id>30].sort_values(["source_provider_id"])
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#      provider_id              provider_name             sys_inserted_x  \
# 491          103           American Express 2019-01-21 19:32:53.867181
# 259          112              Bank Of China 2019-01-21 19:32:53.867181
# 253          102                       CIMB 2019-01-21 19:32:53.867181
# 3            104                   Citibank 2019-01-21 19:32:53.867181
# 129          105                        DBS 2019-01-21 19:32:53.867181
# 128          101            Hitachi Capital 2019-01-21 19:32:53.867181
# 123          106                       HSBC 2019-01-21 19:32:53.867181
# 133          107                    Maybank 2019-01-21 19:32:53.867181
# 258          108                       OCBC 2019-01-21 19:32:53.867181
# 377          109                       POSB 2019-01-21 19:32:53.867181
# 2            100    Standard Chartered Bank 2019-01-21 19:32:53.867181
# 7            110         Standard Chartered 2019-01-21 19:32:53.867181
# 372           99    Standard Chartered Bank 2019-01-21 19:32:53.867181
# 134          111                        UOB 2019-01-21 19:32:53.867181
# 8           1451                       ICBC 2019-03-08 19:33:01.063887
# 23          8289                  CIMB Bank 2019-07-08 19:34:40.254289
# 276        20008                    Revolut 2019-11-01 20:10:32.659247
# 252          844           American Express 2019-02-19 19:32:36.488054
# 376          267                        AIG 2019-02-01 01:43:57.318499
# 373          254       Hong Leong Assurance 2019-02-01 01:43:57.318499
# 257          266               Tokio Marine 2019-02-01 01:43:57.318499
# 130          256         The Wise Traveller 2019-02-01 01:43:57.318499
# 4            255                        AXA 2019-02-01 01:43:57.318499
# 151        19315             Allianz Travel 2019-10-25 20:10:48.998022
# 132          265  Allianz Global Assistance 2019-02-01 01:43:57.318499
# 6            264                        FWD 2019-02-01 01:43:57.318499
# 254          253                      Etiqa 2019-02-01 01:43:57.318499
# 375          263                       ERGO 2019-02-01 01:43:57.318499
# 256          262                       MSIG 2019-02-01 01:43:57.318499
# 255          257                     Sompo  2019-02-01 01:43:57.318499
# 131          261                Direct Asia 2019-02-01 01:43:57.318499
# 5            260                      Aviva 2019-02-01 01:43:57.318499
# 374          259                NTUC Income 2019-02-01 01:43:57.318499
# 395        20738          Liberty Insurance 2019-11-08 20:11:17.267220
# 26         31458                        Tiq 2020-02-04 20:10:42.649533
#
#                  sys_updated_x  source_provider_id                       slug  \
# 491 2019-01-21 19:32:53.867181                51.0           american-express
# 259 2019-01-21 19:32:53.867181                53.0                        boc
# 253 2019-01-21 19:32:53.867181                55.0                       cimb
# 3   2019-01-21 19:32:53.867181                56.0                   citibank
# 129 2019-01-21 19:32:53.867181                58.0                        dbs
# 128 2019-01-21 19:32:53.867181                60.0            hitachi-capital
# 123 2019-01-21 19:32:53.867181                62.0                       hsbc
# 133 2019-01-21 19:32:53.867181                63.0                    maybank
# 258 2019-01-21 19:32:53.867181                64.0                       ocbc
# 377 2019-01-21 19:32:53.867181                65.0                       posb
# 2   2019-01-21 19:32:53.867181                67.0                        scb
# 7   2019-01-21 19:32:53.867181                70.0         standard-chartered
# 372 2019-01-21 19:32:53.867181                71.0    standard-chartered-bank
# 134 2019-01-21 19:32:53.867181                72.0                        uob
# 8   2019-03-08 19:33:01.063887                74.0                       icbc
# 23  2019-07-08 19:34:40.254289                75.0                  cimb-bank
# 276 2019-11-01 20:10:32.659247                76.0                    revolut
# 252 2019-02-19 19:32:36.488054               207.0           american-express
# 376 2019-02-01 01:43:57.318499               244.0                        aig
# 373 2019-02-01 01:43:57.318499               247.0           hong-leong-group
# 257 2019-02-01 01:43:57.318499               252.0               tokio-marine
# 130 2019-02-01 01:43:57.318499               253.0         the-wise-traveller
# 4   2019-02-01 01:43:57.318499               259.0                 axa-direct
# 151 2019-10-25 20:10:48.998022               260.0             allianz-travel
# 132 2019-02-01 01:43:57.318499               260.0  allianz-global-assistance
# 6   2019-02-01 01:43:57.318499               261.0                        fwd
# 254 2019-02-01 01:43:57.318499               262.0                      etiqa
# 375 2019-02-01 01:43:57.318499               263.0         ergo-travelprotect
# 256 2019-02-01 01:43:57.318499               265.0            msig-traveleasy
# 255 2019-02-01 01:43:57.318499               266.0                      sompo
# 131 2019-02-01 01:43:57.318499               286.0                direct-asia
# 5   2019-02-01 01:43:57.318499               287.0                      aviva
# 374 2019-02-01 01:43:57.318499               290.0                ntuc-income
# 395 2019-11-08 20:11:17.267220               291.0          liberty-insurance
# 26  2020-02-04 20:10:42.649533               292.0                        tiq
#
#      status  channel_id  country_id  language_id       channel_key  \
# 491       1           1           1            3           unknown
# 259       1           4           1            1      credit-cards
# 253       0           4           1            1      credit-cards
# 3         1           4           1            1      credit-cards
# 129       1           4           1            1      credit-cards
# 128       0           4           1            1      credit-cards
# 123       1           4           1            1      credit-cards
# 133       1           4           1            1      credit-cards
# 258       1           4           1            1      credit-cards
# 377       1           4           1            1      credit-cards
# 2         0           4           1            1      credit-cards
# 7         1           4           1            1      credit-cards
# 372       0           4           1            1      credit-cards
# 134       1           4           1            1      credit-cards
# 8         1           4           1            1      credit-cards
# 23        0           4           1            1      credit-cards
# 276       0           4           1            1      credit-cards
# 252       1          20           1            1  travel-insurance
# 376       1          20           1            1  travel-insurance
# 373       1          20           1            1  travel-insurance
# 257       1          20           1            1  travel-insurance
# 130       1          20           1            1  travel-insurance
# 4         1          20           1            1  travel-insurance
# 151       1          20           1            1  travel-insurance
# 132       1          20           1            1  travel-insurance
# 6         1          20           1            1  travel-insurance
# 254       1          20           1            1  travel-insurance
# 375       1          20           1            1  travel-insurance
# 256       1          20           1            1  travel-insurance
# 255       1          20           1            1  travel-insurance
# 131       1          20           1            1  travel-insurance
# 5         1          20           1            1  travel-insurance
# 374       1          20           1            1  travel-insurance
# 395       1          20           1            1  travel-insurance
# 26        1          20           1            1  travel-insurance
#
#          channel_name             sys_inserted_y              sys_updated_y
# 491           Unknown 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 259      Credit Cards 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 253      Credit Cards 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 3        Credit Cards 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 129      Credit Cards 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 128      Credit Cards 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 123      Credit Cards 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 133      Credit Cards 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 258      Credit Cards 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 377      Credit Cards 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 2        Credit Cards 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 7        Credit Cards 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 372      Credit Cards 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 134      Credit Cards 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 8        Credit Cards 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 23       Credit Cards 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 276      Credit Cards 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 252  Travel Insurance 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 376  Travel Insurance 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 373  Travel Insurance 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 257  Travel Insurance 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 130  Travel Insurance 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 4    Travel Insurance 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 151  Travel Insurance 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 132  Travel Insurance 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 6    Travel Insurance 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 254  Travel Insurance 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 375  Travel Insurance 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 256  Travel Insurance 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 255  Travel Insurance 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 131  Travel Insurance 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 5    Travel Insurance 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 374  Travel Insurance 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 395  Travel Insurance 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062
# 26   Travel Insurance 2018-09-11 10:11:04.481062 2018-09-11 10:11:04.481062

# %% [markdown]
# ### Channels Observed (manual sense check)

# %%
apply_clicks.columns
# Out:
# Index(['country_code', 'page_type', 'page_sub_type', 'is_embed', 'page_url',
#        'device_os', 'device_category', 'browser', 'channel', 'product_slug',
#        'product', 'product_id', 'product_from_id', 'provider_slug', 'provider',
#        'provider_id', 'provider_from_id', 'affiliate_category',
#        'affiliate_location', 'affiliate_page_type', 'affiliate_widget_type',
#        'list_position', 'action', 'source', 'activity_attributes'],
#       dtype='object')

# %%
apply_clicks.groupby(["channel"]).size().sort_index()
# Out:
# channel
# car-insurance               147
# credit-cards               2574
# debt-consolidation-plan      71
# health-insurance              9
# home-insurance               15
# home-loan                     7
# investments                 141
# maid-insurance               59
# personal-loan              1592
# refinancing                  23
# savings-account              51
# travel-insurance             58
# dtype: int64
