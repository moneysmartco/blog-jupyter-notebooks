# %%
from datetime import datetime, timedelta
import numpy as np
import pandas as pd
import csv

import athena_querying  #doing this style as there are connection details within that I want to scope

# %%
# Expand to screen width to fit more on.
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
num_days_to_query = 7
to_datetime = datetime.now().date() - timedelta(days=1) #datetime(year=2020, month=3, day=1)
from_datetime = to_datetime - timedelta(days=num_days_to_query)

event_definition_csv = "./Event Definitions/MS Event Categories.csv"
consumer_allowed_fields_file = "./Event Definitions/schema.py"

# %%
event_defs_raw = pd.read_csv(event_definition_csv, header=1)[1:]

# %%
event_defs_raw.head()
# Out:
#   Unnamed: 0                      Event Name  \
# 1          1  LeadGeneration.ClickConversion
# 2        NaN                             NaN
# 3        NaN                             NaN
# 4        NaN                             NaN
# 5        NaN                             NaN
#
#                                          Description  \
# 1  Tracks events that lead directly to a conversi...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#                                  Sample button\n/URL Property Name isMandated  \
# 1  - Apply Now\n- Buy Now\n- GoToSite\n- Learn Mo...       channel       TRUE
# 2                                                NaN      pageType       TRUE
# 3                                                NaN      language       TRUE
# 4                                                NaN       country       TRUE
# 5                                                NaN      provider       TRUE
#
#   Property Value Type               Property Description  \
# 1              string                    Product channel
# 2              string           Type of page user landed
# 3              string                 Locale of the page
# 4              string  which market this events happened
# 5              string  Unique Identifier of the provider
#
#   Suggested values (Red colored values are fixed allowed values)  \
# 1  home-loan,refinancing,home-equity-loan,renovat...
# 2  home-page,product-listing,product-details,blog...
# 3                                           en,zh-hk
# 4                                     sg,hk,tw,ph,id
# 5                                           citibank
#
#             Standardisation  ... Home Loan - Mortgage Calculator  \
# 1  Listing and details page  ...                             NaN
# 2                       NaN  ...                             NaN
# 3                       NaN  ...                             NaN
# 4                       NaN  ...                             NaN
# 5                       NaN  ...                             NaN
#
#   Home Loan - Progressive Payment Calculator  \
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
#
#   Home Loan - Property Valuation Calculator  \
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
#
#   Home Loan HK - Mortgage Calculator  \
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
#
#   Home Loan HK - Property Valuation Calculator Mortgage Home Page  \
# 1                                          NaN                NaN
# 2                                          NaN                NaN
# 3                                          NaN                NaN
# 4                                          NaN                NaN
# 5                                          NaN                NaN
#
#   New Purchase Home Page Refinance Home Page New Listing Service\nHK TI  \
# 1                    NaN                 NaN           travel-insurance
# 2                    NaN                 NaN                        NaN
# 3                    NaN                 NaN                    buy-now
# 4                    NaN                 NaN                     eg 331
# 5                    NaN                 NaN                       eg 4
#
#                                Product Widgets
# 1  credit-cards,personal-loan,travel-insurance
# 2                                          NaN
# 3                                  left blanks
# 4     integer value greater than or equal to 1
# 5     integer value greater than or equal to 1
#
# [5 rows x 32 columns]

# %%
cols_of_interest = ["Event Name", "Property Name", "isMandated", "Property Value Type"]

# %%
event_defs_raw.columns
# Out:
# Index(['Unnamed: 0', 'Event Name', 'Description', 'Sample button\n/URL',
#        'Property Name', 'isMandated', 'Property Value Type',
#        'Property Description',
#        'Suggested values (Red colored values are fixed allowed values)',
#        'Standardisation', 'DBS/POSB SG PL Full API', 'SCB SG CC Full API',
#        'SCB SG PL Full API', 'OCBC Bot Service', 'CI FWD ', 'CI Etiqa',
#        'CI Wizard', 'Home Loan - TDSR Calculator',
#        'Home Loan - Property Tax Calculator',
#        'Home Loan - Stamp Duty Calculator', 'Home Loan - Refinance Calculator',
#        'Home Loan - MSR Calculator', 'Home Loan - Mortgage Calculator',
#        'Home Loan - Progressive Payment Calculator',
#        'Home Loan - Property Valuation Calculator',
#        'Home Loan HK - Mortgage Calculator',
#        'Home Loan HK - Property Valuation Calculator', 'Mortgage Home Page',
#        'New Purchase Home Page', 'Refinance Home Page',
#        'New Listing Service\nHK TI', 'Product Widgets'],
#       dtype='object')

# %%
event_defs_raw[["Event Name",]] = event_defs_raw[["Event Name",]].fillna(method='ffill') # fill down the event name to make it more database-y
event_defs = event_defs_raw[cols_of_interest][~event_defs_raw["Property Name"].isna()] # There's some empty space rows in the source

# %%
# Create snake case version
# This so feels like an interview question to do it more efficiently
def camelcaseify(event_name):
    ret = ""
    for c in event_name:
        c_lower = c.lower()
        if c==c_lower:
            ret+=c
        else:
            ret+="_"+c_lower
    return ret
    
event_defs["property_name"] = event_defs.apply(lambda x: camelcaseify(x["Property Name"]), axis=1)

# %%
event_defs.groupby(["Event Name"]).count() # will be lower if some nulls
# Out:
#                                          Property Name  isMandated  \
# Event Name
# ABTest.Conversion                                    2           0
# EmailCapture                                         7           7
# LeadGeneration.ClickConversion                      22          22
# LeadGeneration.FormStepCompleted                    12          12
# LeadGeneration.FormSubmitted                         9           9
# LeadGeneration.PaymentCompleted                      8           8
# LeadGeneration.ThankYou                              4           4
# Reading                                              6           6
# UserAuth.LoggedIn                                    5           5
# UserAuth.LoggedOut                                   4           4
# UserAuth.RegisteredAccount                           4           4
# UserEngagement.ButtonClick                           7           7
# UserEngagement.ClickedFilter                        13          13
# UserEngagement.ClickedMenuItem                       7           7
# UserEngagement.ListingProductImpression             15          15
# UserEngagement.QuestionAnswered                      9           9
# UserEngagement.ResetFilter                           5           5
# UserEngagement.Search                                3           3
# UserEngagement.SearchResult                          5           5
# UserEngagement.ShowMoreFilter                        5           5
# UserEngagement.ShowMoreOptions                       7           7
# UserEngagement.ShowedMoreDetails                    20          20
# UserEngagement.SortedList                            6           6
# UserEngagement.UsedHelpHints                         7           7
# UserEngagement.ViewedMoreDetails                    20          20
# UserFeedback.FeedbackSubmitted                       1           0
# UserFeedback.MoodSubmitted                           1           0
# UserFeedback.MoreFeedback                            1           0
# UserView.WidgetLoad                                 10          10
#
#                                          Property Value Type  property_name
# Event Name
# ABTest.Conversion                                          2              2
# EmailCapture                                               7              7
# LeadGeneration.ClickConversion                            22             22
# LeadGeneration.FormStepCompleted                          12             12
# LeadGeneration.FormSubmitted                               9              9
# LeadGeneration.PaymentCompleted                            8              8
# LeadGeneration.ThankYou                                    4              4
# Reading                                                    3              6
# UserAuth.LoggedIn                                          5              5
# UserAuth.LoggedOut                                         4              4
# UserAuth.RegisteredAccount                                 4              4
# UserEngagement.ButtonClick                                 7              7
# UserEngagement.ClickedFilter                              13             13
# UserEngagement.ClickedMenuItem                             7              7
# UserEngagement.ListingProductImpression                   15             15
# UserEngagement.QuestionAnswered                            9              9
# UserEngagement.ResetFilter                                 5              5
# UserEngagement.Search                                      3              3
# UserEngagement.SearchResult                                5              5
# UserEngagement.ShowMoreFilter                              5              5
# UserEngagement.ShowMoreOptions                             7              7
# UserEngagement.ShowedMoreDetails                          20             20
# UserEngagement.SortedList                                  6              6
# UserEngagement.UsedHelpHints                               7              7
# UserEngagement.ViewedMoreDetails                          20             20
# UserFeedback.FeedbackSubmitted                             1              1
# UserFeedback.MoodSubmitted                                 1              1
# UserFeedback.MoreFeedback                                  1              1
# UserView.WidgetLoad                                       10             10

# %%
# Events missing a property value being set
event_defs[event_defs["Property Value Type"].isna()]
# Out:
#     Event Name Property Name isMandated Property Value Type property_name
# 225    Reading        status       TRUE                 NaN        status
# 229    Reading      page_url       TRUE                 NaN      page_url
# 230    Reading         title       TRUE                 NaN         title

# %%
# Events with spaces in them
event_defs[event_defs["Event Name"].str.contains(" ")]
# Out:
# Empty DataFrame
# Columns: [Event Name, Property Name, isMandated, Property Value Type, property_name]
# Index: []

# %%
event_defs.groupby(["Property Value Type"]).count()
# Out:
#                      Event Name  Property Name  isMandated  property_name
# Property Value Type
# string                      216            216         211            216
# string/JSON                   2              2           2              2
# string/json                   4              4           4              4

# %%
# Interpret the expected values (not currently possible due to the spreadsheet format)

# %%
# Check that there aren't duplicates
event_nps = event_defs.groupby(["Event Name", "Property Name"]).count()

# %%
event_nps[event_nps.property_name>1]
# Out:
#                                                 isMandated  \
# Event Name                     Property Name
# LeadGeneration.ClickConversion productCategory           2
#                                provider                  2
#
#                                                 Property Value Type  \
# Event Name                     Property Name
# LeadGeneration.ClickConversion productCategory                    2
#                                provider                           2
#
#                                                 property_name
# Event Name                     Property Name
# LeadGeneration.ClickConversion productCategory              2
#                                provider                     2

# %%
# Very Crude Loading of Allowed Structure from consumer
with open(consumer_allowed_fields_file) as f:
    consumer_raw_defs = f.read()

# %%
consumer_raw_defs_data = consumer_raw_defs.split("StructField('data', StructType([", 1)[1]\
    .split("StructField('sent_at', StringType(), True),", 1)[0]

# %%
consumer_raw_defs_data = "\n".join([ z for z in consumer_raw_defs_data.split("\n")[:-3] if z.strip()!=""])

# %%
print(consumer_raw_defs_data)
# Out:
#             StructField('title', StringType(), True),
#             StructField('status', StringType(), True),
#             StructField('page_url', StringType(), True),
#             StructField('email_id', StringType(), True),
#             StructField('form_type', StringType(), True),
#             StructField('username', StringType(), True),
#             StructField('sort_order',StringType(),True),
#             StructField('sort_field_name',StringType(),True),
#             StructField('page_path',StringType(),True),
#             StructField('auth_status',StringType(),True),
#             StructField('type',StringType(),True),
#             StructField('cta_type',StringType(),True),
#             StructField('product_id',StringType(),True),
#             StructField('product_name',StringType(),True),
#             StructField('provider_id',StringType(),True),
#             StructField('list_position',StringType(),True),
#             StructField('is_sponsored',StringType(),True),
#             StructField('additional_parameters',
#                 StructType([
#                     StructField('original_price', StringType(), True),
#                     StructField('discounted_price',StringType(),True)
#                 ]),True),
#             StructField('event_type',StringType(),True),
#             StructField('object_clicked',StringType(),True),
#             StructField('borrow_amount',StringType(),True),
#             StructField('loan_duration_in_years',StringType(),True),
#             StructField('citizenship',StringType(),True),
#             StructField('is_recommended',StringType(),True),
#             StructField('question_number',StringType(),True),
#             StructField('question_answer',StringType(),True),
#             StructField('loan_type',StringType(),True),
#             StructField('property_type',StringType(),True),
#             StructField('remaining_loan',StringType(),True),
#             StructField('current_rate',StringType(),True),
#             StructField('remaining_tenure',StringType(),True),
#             StructField('current_bank',StringType(),True),
#             StructField('rate_type',StringType(),True),
#             StructField('loan_tenure',StringType(),True),
#             StructField('is_paid',StringType(),True),
#             StructField('action',StringType(),True),
#             StructField('form_step',StringType(),True),
#             StructField('form_name',StringType(),True),
#             StructField('car_make',StringType(),True),
#             StructField('ncd',StringType(),True),
#             StructField('gender',StringType(),True),
#             StructField('birthdate',StringType(),True),
#             StructField('policy_expiring',StringType(),True),
#             StructField('age',StringType(),True),
#             StructField('filters',
#                 StructType([
#                     StructField('0',StringType(),True),
#                     StructField('1',StringType(),True),
#                     StructField('2',StringType(),True),
#                     StructField('3',StringType(),True),
#                     StructField('4',StringType(),True),
#                     StructField('type',StringType(),True),
#                     StructField('location',StringType(),True),
#                     StructField('start_date',StringType(),True),
#                     StructField('end_date',StringType(),True),
#                     StructField('adults',StringType(),True),
#                     StructField('children',StringType(),True),
#                     StructField('insurer',StringType(),True),
#                     StructField('name',StringType(),True),
#                     StructField('cover',StringType(),True),
#                     StructField('covered',StringType(),True),
#                     StructField('product_category',StringType(),True),
#                     StructField('provider_name',StringType(),True)
#                 ]),True),
#             StructField('language',StringType(),True),
#             StructField('provider',StringType(),True),
#             StructField('product_category',StringType(),True),
#             StructField('page_type',StringType(),True),
#             StructField('country', StringType(), True),
#             StructField('channel', StringType(), True),
#             StructField('product',StringType(),True),
#             StructField('search',StringType(),True),
#             StructField('affiliate_widget_type',StringType(),True),
#             StructField('affiliate_category',StringType(),True),
#             StructField('affiliate_page_type',StringType(),True),
#             StructField('affiliate_location',StringType(),True),
#             StructField('source',StringType(),True),
#             StructField('source_id',StringType(),True),
#             StructField('login_method',StringType(),True),
#             StructField('product_category_id',StringType(),True),
#             StructField('sequence',StringType(),True),

# %%
import string

# %%
consumer_raw_defs_data_lines = consumer_raw_defs_data.split("\n")
print(len(consumer_raw_defs_data_lines))
# Out:
# 85

# %%
top_level_indent = [i for i, z in enumerate(consumer_raw_defs_data_lines[0]) if z in string.ascii_letters][0]

# %%
top_level_indent
# Out:
# 12

# %%
allowed_values = []
for line in consumer_raw_defs_data_lines:
    indent = [i for i, z in enumerate(line) if z in string.ascii_letters][0]
    if indent != top_level_indent:
        continue
    allowed_values.append(line.split("'")[1])

# %%
print(len(allowed_values))
# Out:
# 62

# %%
allowed_values
# Out:
# ['title',
#  'status',
#  'page_url',
#  'email_id',
#  'form_type',
#  'username',
#  'sort_order',
#  'sort_field_name',
#  'page_path',
#  'auth_status',
#  'type',
#  'cta_type',
#  'product_id',
#  'product_name',
#  'provider_id',
#  'list_position',
#  'is_sponsored',
#  'additional_parameters',
#  'event_type',
#  'object_clicked',
#  'borrow_amount',
#  'loan_duration_in_years',
#  'citizenship',
#  'is_recommended',
#  'question_number',
#  'question_answer',
#  'loan_type',
#  'property_type',
#  'remaining_loan',
#  'current_rate',
#  'remaining_tenure',
#  'current_bank',
#  'rate_type',
#  'loan_tenure',
#  'is_paid',
#  'action',
#  'form_step',
#  'form_name',
#  'car_make',
#  'ncd',
#  'gender',
#  'birthdate',
#  'policy_expiring',
#  'age',
#  'filters',
#  'language',
#  'provider',
#  'product_category',
#  'page_type',
#  'country',
#  'channel',
#  'product',
#  'search',
#  'affiliate_widget_type',
#  'affiliate_category',
#  'affiliate_page_type',
#  'affiliate_location',
#  'source',
#  'source_id',
#  'login_method',
#  'product_category_id',
#  'sequence']

# %%
# Event defs with properties that will be rejected (at the high level only)

event_defs[~event_defs["property_name"].isin(allowed_values)]
# Out:
#                                   Event Name     Property Name isMandated  \
# 11            LeadGeneration.ClickConversion      pageReferrer       TRUE
# 31          LeadGeneration.FormStepCompleted             error      FALSE
# 32          LeadGeneration.FormStepCompleted       formDetails      FALSE
# 41              LeadGeneration.FormSubmitted       formDetails      FALSE
# 68          UserEngagement.ShowedMoreDetails      pageReferrer       TRUE
# 89          UserEngagement.ViewedMoreDetails      pageReferrer       TRUE
# 103             UserEngagement.UsedHelpHints          hintType       TRUE
# 104             UserEngagement.UsedHelpHints          hintName       TRUE
# 109             UserEngagement.UsedHelpHints   interactionType       TRUE
# 110           UserEngagement.ClickedMenuItem          menuName       TRUE
# 114           UserEngagement.ClickedMenuItem      menuItemName       TRUE
# 115           UserEngagement.ClickedMenuItem        targetPath      FALSE
# 116           UserEngagement.ClickedMenuItem     targetChannel      FALSE
# 130            UserEngagement.ShowMoreFilter        filterType       TRUE
# 142             UserEngagement.ClickedFilter        filterType       TRUE
# 144             UserEngagement.ClickedFilter        filterStep      FALSE
# 155               UserEngagement.ResetFilter        filterType       TRUE
# 156                    UserEngagement.Search     searchKeyword       TRUE
# 163              UserEngagement.SearchResult    searchResponse       TRUE
# 176  UserEngagement.ListingProductImpression      pageReferrer       TRUE
# 200               UserFeedback.MoodSubmitted        moodRating        NaN
# 201           UserFeedback.FeedbackSubmitted          feedback        NaN
# 202                UserFeedback.MoreFeedback      moreFeedback        NaN
# 203                        ABTest.Conversion     experiment_id        NaN
# 204                        ABTest.Conversion  experiment_value        NaN
# 219                             EmailCapture          userName       TRUE
#
#     Property Value Type     property_name
# 11               string     page_referrer
# 31               string             error
# 32          string/json      form_details
# 41          string/json      form_details
# 68               string     page_referrer
# 89               string     page_referrer
# 103              string         hint_type
# 104              string         hint_name
# 109              string  interaction_type
# 110              string         menu_name
# 114              string    menu_item_name
# 115              string       target_path
# 116              string    target_channel
# 130              string       filter_type
# 142              string       filter_type
# 144              string       filter_step
# 155              string       filter_type
# 156              string    search_keyword
# 163         string/JSON   search_response
# 176              string     page_referrer
# 200              string       mood_rating
# 201              string          feedback
# 202              string     more_feedback
# 203              string     experiment_id
# 204              string  experiment_value
# 219              string         user_name
